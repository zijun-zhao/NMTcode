# %%
import pickle
pickle_in = open("/home/penglab/FeaCal/apHIER_ns.pickle","rb")
example_ = pickle.load(pickle_in)

# %% [markdown]
# ### Research Ribbon Color

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
# %matplotlib inline

import neuro_morpho_toolbox as nmt
# ns=nmt.neuron_set('/Users/pengxie/Documents/Research/fullMorph_classification/data/registered_swc/Janelia_test/swc/Whole/')
ns_xie = example_[0]

# %%
keepc= ['C1', 'C10', 'C11', 'C12', 'C13', 'C14', 'C16', 'C17',
       'C18', 'C19', 'C2', 'C3', 'C4', 'C6', 'C7', 'C8',
       'C9']

# %%
keepidx=[]
for i in keepc:
    for ii in (ns_xie.metadata[ns_xie.metadata['Cluster']==i]).index:
        print (ii+str(','))
# Out:
# AA0038,
# AA0039,
# AA0041,
# AA0043,
# AA0101,
# AA0103,
# AA0104,
# AA0105,
# AA0178,
# AA0183,
# AA0185,
# AA0186,
# AA0187,
# AA0188,
# AA0231,
# AA0239,
# AA0242,
# AA0266,
# AA0277,
# AA0278,
# AA0294,
# AA0390,
# AA0394,
# AA0398,
# AA0399,
# AA0405,
# AA0406,
# AA0457,
# AA0544,
# AA0545,
# AA0548,
# AA0550,
# AA0554,
# AA0558,
# AA0577,
# AA0596,
# AA0599,
# AA0605,
# AA0610,
# AA0616,
# AA0623,
# AA0625,
# AA0626,
# AA0628,
# AA0630,
# AA0633,
# AA0634,
# AA0635,
# AA0637,
# AA0640,
# AA0641,
# AA0642,
# AA0647,
# AA0648,
# AA0649,
# AA0650,
# AA0652,
# AA0654,
# AA0667,
# AA0727,
# AA0732,
# AA0733,
# AA0737,
# AA0740,
# AA0766,
# AA0769,
# AA0770,
# AA0781,
# AA0783,
# AA0784,
# AA0785,
# AA0787,
# AA0799,
# AA0817,
# AA0832,
# AA0833,
# AA0835,
# AA0836,
# AA0837,
# AA0838,
# AA0839,
# AA0844,
# AA0846,
# AA0854,
# AA0856,
# AA0863,
# AA0892,
# AA0893,
# AA0898,
# AA0899,
# AA0004,
# AA0009,
# AA0023,
# AA0051,
# AA0176,
# AA0226,
# AA0238,
# AA0293,
# AA0321,
# AA0322,
# AA0330,
# AA0344,
# AA0352,
# AA0355,
# AA0356,
# AA0365,
# AA0367,
# AA0391,
# AA0448,
# AA0519,
# AA0579,
# AA0580,
# AA0598,
# AA0612,
# AA0692,
# AA0693,
# AA0719,
# AA0904,
# AA0058,
# AA0124,
# AA0125,
# AA0139,
# AA0158,
# AA0161,
# AA0246,
# AA0247,
# AA0252,
# AA0306,
# AA0380,
# AA0383,
# AA0423,
# AA0459,
# AA0476,
# AA0477,
# AA0478,
# AA0499,
# AA0532,
# AA0538,
# AA0546,
# AA0551,
# AA0566,
# AA0569,
# AA0574,
# AA0613,
# AA0621,
# AA0631,
# AA0683,
# AA0684,
# AA0687,
# AA0704,
# AA0706,
# AA0709,
# AA0721,
# AA0736,
# AA0811,
# AA0815,
# AA0816,
# AA0818,
# AA0819,
# AA0820,
# AA0824,
# AA0825,
# AA0834,
# AA0847,
# AA0848,
# AA0849,
# AA0850,
# AA0851,
# AA0855,
# AA0864,
# AA0885,
# AA0890,
# AA0910,
# AA0014,
# AA0037,
# AA0061,
# AA0066,
# AA0075,
# AA0083,
# AA0089,
# AA0094,
# AA0095,
# AA0097,
# AA0110,
# AA0111,
# AA0113,
# AA0229,
# AA0234,
# AA0235,
# AA0241,
# AA0276,
# AA0280,
# AA0286,
# AA0295,
# AA0298,
# AA0325,
# AA0354,
# AA0358,
# AA0363,
# AA0368,
# AA0369,
# AA0370,
# AA0371,
# AA0373,
# AA0403,
# AA0410,
# AA0418,
# AA0455,
# AA0463,
# AA0556,
# AA0590,
# AA0601,
# AA0602,
# AA0636,
# AA0644,
# AA0660,
# AA0664,
# AA0675,
# AA0765,
# AA0771,
# AA0775,
# AA0776,
# AA0777,
# AA0778,
# AA0786,
# AA0789,
# AA0797,
# AA0800,
# AA0803,
# AA0807,
# AA0845,
# AA0862,
# AA0867,
# AA0868,
# AA0872,
# AA0874,
# AA0888,
# AA0901,
# AA0902,
# AA0903,
# AA0907,
# AA0908,
# AA0913,
# AA0929,
# AA0022,
# AA0031,
# AA0071,
# AA0079,
# AA0088,
# AA0126,
# AA0138,
# AA0159,
# AA0173,
# AA0227,
# AA0251,
# AA0253,
# AA0283,
# AA0375,
# AA0381,
# AA0384,
# AA0387,
# AA0444,
# AA0468,
# AA0479,
# AA0490,
# AA0493,
# AA0494,
# AA0495,
# AA0500,
# AA0522,
# AA0523,
# AA0530,
# AA0559,
# AA0563,
# AA0565,
# AA0567,
# AA0570,
# AA0657,
# AA0681,
# AA0682,
# AA0688,
# AA0689,
# AA0696,
# AA0703,
# AA0717,
# AA0720,
# AA0810,
# AA0813,
# AA0822,
# AA0843,
# AA0860,
# AA0861,
# AA0875,
# AA0886,
# AA0894,
# AA0909,
# AA0912,
# AA0020,
# AA0021,
# AA0024,
# AA0026,
# AA0030,
# AA0032,
# AA0033,
# AA0072,
# AA0157,
# AA0168,
# AA0170,
# AA0171,
# AA0203,
# AA0254,
# AA0255,
# AA0256,
# AA0258,
# AA0374,
# AA0376,
# AA0377,
# AA0378,
# AA0379,
# AA0382,
# AA0385,
# AA0386,
# AA0392,
# AA0414,
# AA0454,
# AA0458,
# AA0480,
# AA0482,
# AA0483,
# AA0524,
# AA0525,
# AA0526,
# AA0528,
# AA0529,
# AA0531,
# AA0536,
# AA0547,
# AA0552,
# AA0686,
# AA0690,
# AA0695,
# AA0700,
# AA0701,
# AA0705,
# AA0707,
# AA0708,
# AA0710,
# AA0713,
# AA0714,
# AA0715,
# AA0716,
# AA0722,
# AA0723,
# AA0724,
# AA0725,
# AA0805,
# AA0812,
# AA0871,
# AA0877,
# AA0878,
# AA0879,
# AA0881,
# AA0891,
# AA0056,
# AA0086,
# AA0087,
# AA0090,
# AA0128,
# AA0136,
# AA0152,
# AA0153,
# AA0164,
# AA0167,
# AA0172,
# AA0174,
# AA0175,
# AA0177,
# AA0200,
# AA0204,
# AA0205,
# AA0206,
# AA0210,
# AA0211,
# AA0212,
# AA0213,
# AA0214,
# AA0215,
# AA0216,
# AA0217,
# AA0218,
# AA0219,
# AA0220,
# AA0221,
# AA0222,
# AA0223,
# AA0428,
# AA0433,
# AA0443,
# AA0449,
# AA0486,
# AA0488,
# AA0501,
# AA0511,
# AA0537,
# AA0542,
# AA0555,
# AA0557,
# AA0609,
# AA0615,
# AA0730,
# AA0751,
# AA0752,
# AA0760,
# AA0761,
# AA0762,
# AA0768,
# AA0808,
# AA0852,
# AA0917,
# AA0932,
# AA0987,
# AA0989,
# AA0992,
# AA0017,
# AA0077,
# AA0080,
# AA0081,
# AA0082,
# AA0084,
# AA0092,
# AA0093,
# AA0141,
# AA0142,
# AA0163,
# AA0207,
# AA0209,
# AA0273,
# AA0389,
# AA0429,
# AA0430,
# AA0431,
# AA0432,
# AA0434,
# AA0435,
# AA0436,
# AA0437,
# AA0438,
# AA0503,
# AA0504,
# AA0505,
# AA0506,
# AA0507,
# AA0508,
# AA0509,
# AA0510,
# AA0512,
# AA0513,
# AA0514,
# AA0515,
# AA0516,
# AA0517,
# AA0521,
# AA0606,
# AA0607,
# AA0608,
# AA0614,
# AA0718,
# AA0729,
# AA0779,
# AA0922,
# AA0924,
# AA0928,
# AA0930,
# AA0931,
# AA0933,
# AA0934,
# AA0935,
# AA0936,
# AA0937,
# AA0938,
# AA0939,
# AA0940,
# AA0941,
# AA0943,
# AA0946,
# AA0947,
# AA0948,
# AA0950,
# AA0951,
# AA0953,
# AA0954,
# AA0955,
# AA0957,
# AA0958,
# AA0961,
# AA0962,
# AA0963,
# AA0965,
# AA0966,
# AA0967,
# AA0969,
# AA0970,
# AA0971,
# AA0972,
# AA0973,
# AA0974,
# AA0975,
# AA0976,
# AA0978,
# AA0979,
# AA0980,
# AA0981,
# AA0982,
# AA0983,
# AA0984,
# AA0985,
# AA0986,
# AA0988,
# AA0990,
# AA0991,
# AA0993,
# AA0995,
# AA0996,
# AA1001,
# AA0015,
# AA0016,
# AA0018,
# AA0019,
# AA0025,
# AA0029,
# AA0052,
# AA0053,
# AA0068,
# AA0070,
# AA0073,
# AA0076,
# AA0194,
# AA0195,
# AA0199,
# AA0208,
# AA0248,
# AA0257,
# AA0357,
# AA0489,
# AA0491,
# AA0496,
# AA0497,
# AA0498,
# AA0527,
# AA0535,
# AA0539,
# AA0540,
# AA0560,
# AA0562,
# AA0564,
# AA0611,
# AA0620,
# AA0685,
# AA0694,
# AA0697,
# AA0728,
# AA0731,
# AA0804,
# AA0821,
# AA0823,
# AA0826,
# AA0827,
# AA0828,
# AA0829,
# AA0830,
# AA0831,
# AA0918,
# AA0078,
# AA0123,
# AA0151,
# AA0154,
# AA0155,
# AA0156,
# AA0165,
# AA0189,
# AA0191,
# AA0192,
# AA0259,
# AA0307,
# AA0308,
# AA0309,
# AA0420,
# AA0533,
# AA0561,
# AA0568,
# AA0571,
# AA0572,
# AA0573,
# AA0661,
# AA0869,
# AA0959,
# AA0960,
# AA0997,
# AA0999,
# AA1002,
# AA0091,
# AA0143,
# AA0144,
# AA0145,
# AA0146,
# AA0147,
# AA0148,
# AA0149,
# AA0150,
# AA0162,
# AA0166,
# AA0193,
# AA0196,
# AA0197,
# AA0198,
# AA0202,
# AA0303,
# AA0304,
# AA0305,
# AA0360,
# AA0361,
# AA0362,
# AA0484,
# AA0487,
# AA0998,

# %%
keepidx = ['AA0038','AA0039','AA0041','AA0043','AA0101','AA0103','AA0104','AA0105','AA0178','AA0183','AA0185','AA0186','AA0187','AA0188','AA0231','AA0239','AA0242','AA0266','AA0277','AA0278','AA0294','AA0390','AA0394','AA0398','AA0399','AA0405','AA0406','AA0457','AA0544','AA0545','AA0548','AA0550','AA0554','AA0558','AA0577','AA0596','AA0599','AA0605','AA0610','AA0616','AA0623','AA0625','AA0626','AA0628','AA0630','AA0633','AA0634','AA0635','AA0637','AA0640','AA0641','AA0642','AA0647','AA0648','AA0649','AA0650','AA0652','AA0654','AA0667','AA0727','AA0732','AA0733','AA0737','AA0740','AA0766','AA0769','AA0770','AA0781','AA0783','AA0784','AA0785','AA0787','AA0799','AA0817','AA0832','AA0833','AA0835','AA0836','AA0837','AA0838','AA0839','AA0844','AA0846','AA0854','AA0856','AA0863','AA0892','AA0893','AA0898','AA0899','AA0004','AA0009','AA0023','AA0051','AA0176','AA0226','AA0238','AA0293','AA0321','AA0322','AA0330','AA0344','AA0352','AA0355','AA0356','AA0365','AA0367','AA0391','AA0448','AA0519','AA0579','AA0580','AA0598','AA0612','AA0692','AA0693','AA0719','AA0904','AA0058','AA0124','AA0125','AA0139','AA0158','AA0161','AA0246','AA0247','AA0252','AA0306','AA0380','AA0383','AA0423','AA0459','AA0476','AA0477','AA0478','AA0499','AA0532','AA0538','AA0546','AA0551','AA0566','AA0569','AA0574','AA0613','AA0621','AA0631','AA0683','AA0684','AA0687','AA0704','AA0706','AA0709','AA0721','AA0736','AA0811','AA0815','AA0816','AA0818','AA0819','AA0820','AA0824','AA0825','AA0834','AA0847','AA0848','AA0849','AA0850','AA0851','AA0855','AA0864','AA0885','AA0890','AA0910','AA0014','AA0037','AA0061','AA0066','AA0075','AA0083','AA0089','AA0094','AA0095','AA0097','AA0110','AA0111','AA0113','AA0229','AA0234','AA0235','AA0241','AA0276','AA0280','AA0286','AA0295','AA0298','AA0325','AA0354','AA0358','AA0363','AA0368','AA0369','AA0370','AA0371','AA0373','AA0403','AA0410','AA0418','AA0455','AA0463','AA0556','AA0590','AA0601','AA0602','AA0636','AA0644','AA0660','AA0664','AA0675','AA0765','AA0771','AA0775','AA0776','AA0777','AA0778','AA0786','AA0789','AA0797','AA0800','AA0803','AA0807','AA0845','AA0862','AA0867','AA0868','AA0872','AA0874','AA0888','AA0901','AA0902','AA0903','AA0907','AA0908','AA0913','AA0929','AA0022','AA0031','AA0071','AA0079','AA0088','AA0126','AA0138','AA0159','AA0173','AA0227','AA0251','AA0253','AA0283','AA0375','AA0381','AA0384','AA0387','AA0444','AA0468','AA0479','AA0490','AA0493','AA0494','AA0495','AA0500','AA0522','AA0523','AA0530','AA0559','AA0563','AA0565','AA0567','AA0570','AA0657','AA0681','AA0682','AA0688','AA0689','AA0696','AA0703','AA0717','AA0720','AA0810','AA0813','AA0822','AA0843','AA0860','AA0861','AA0875','AA0886','AA0894','AA0909','AA0912','AA0020','AA0021','AA0024','AA0026','AA0030','AA0032','AA0033','AA0072','AA0157','AA0168','AA0170','AA0171','AA0203','AA0254','AA0255','AA0256','AA0258','AA0374','AA0376','AA0377','AA0378','AA0379','AA0382','AA0385','AA0386','AA0392','AA0414','AA0454','AA0458','AA0480','AA0482','AA0483','AA0524','AA0525','AA0526','AA0528','AA0529','AA0531','AA0536','AA0547','AA0552','AA0686','AA0690','AA0695','AA0700','AA0701','AA0705','AA0707','AA0708','AA0710','AA0713','AA0714','AA0715','AA0716','AA0722','AA0723','AA0724','AA0725','AA0805','AA0812','AA0871','AA0877','AA0878','AA0879','AA0881','AA0891','AA0056','AA0086','AA0087','AA0090','AA0128','AA0136','AA0152','AA0153','AA0164','AA0167','AA0172','AA0174','AA0175','AA0177','AA0200','AA0204','AA0205','AA0206','AA0210','AA0211','AA0212','AA0213','AA0214','AA0215','AA0216','AA0217','AA0218','AA0219','AA0220','AA0221','AA0222','AA0223','AA0428','AA0433','AA0443','AA0449','AA0486','AA0488','AA0501','AA0511','AA0537','AA0542','AA0555','AA0557','AA0609','AA0615','AA0730','AA0751','AA0752','AA0760','AA0761','AA0762','AA0768','AA0808','AA0852','AA0917','AA0932','AA0987','AA0989','AA0992','AA0017','AA0077','AA0080','AA0081','AA0082','AA0084','AA0092','AA0093','AA0141','AA0142','AA0163','AA0207','AA0209','AA0273','AA0389','AA0429','AA0430','AA0431','AA0432','AA0434','AA0435','AA0436','AA0437','AA0438','AA0503','AA0504','AA0505','AA0506','AA0507','AA0508','AA0509','AA0510','AA0512','AA0513','AA0514','AA0515','AA0516','AA0517','AA0521','AA0606','AA0607','AA0608','AA0614','AA0718','AA0729','AA0779','AA0922','AA0924','AA0928','AA0930','AA0931','AA0933','AA0934','AA0935','AA0936','AA0937','AA0938','AA0939','AA0940','AA0941','AA0943','AA0946','AA0947','AA0948','AA0950','AA0951','AA0953','AA0954','AA0955','AA0957','AA0958','AA0961','AA0962','AA0963','AA0965','AA0966','AA0967','AA0969','AA0970','AA0971','AA0972','AA0973','AA0974','AA0975','AA0976','AA0978','AA0979','AA0980','AA0981','AA0982','AA0983','AA0984','AA0985','AA0986','AA0988','AA0990','AA0991','AA0993','AA0995','AA0996','AA1001','AA0015','AA0016','AA0018','AA0019','AA0025','AA0029','AA0052','AA0053','AA0068','AA0070','AA0073','AA0076','AA0194','AA0195','AA0199','AA0208','AA0248','AA0257','AA0357','AA0489','AA0491','AA0496','AA0497','AA0498','AA0527','AA0535','AA0539','AA0540','AA0560','AA0562','AA0564','AA0611','AA0620','AA0685','AA0694','AA0697','AA0728','AA0731','AA0804','AA0821','AA0823','AA0826','AA0827','AA0828','AA0829','AA0830','AA0831','AA0918','AA0078','AA0123','AA0151','AA0154','AA0155','AA0156','AA0165','AA0189','AA0191','AA0192','AA0259','AA0307','AA0308','AA0309','AA0420','AA0533','AA0561','AA0568','AA0571','AA0572','AA0573','AA0661','AA0869','AA0959','AA0960','AA0997','AA0999','AA1002','AA0091','AA0143','AA0144','AA0145','AA0146','AA0147','AA0148','AA0149','AA0150','AA0162','AA0166','AA0193','AA0196','AA0197','AA0198','AA0202','AA0303','AA0304','AA0305','AA0360','AA0361','AA0362','AA0484','AA0487','AA0998']

# %%
ns_xie.metadata = ns_xie.metadata .loc[keepidx,:]
ns_xie.UMAP = ns_xie.UMAP.loc[keepidx,:]

# %% [markdown]
# ## function fromSOMAtoAXON() will return a dataframe
# * first a DataFrame will be generated,
#
# * **clusterDF** stores the information of clustering result, with columns ['swc list', 'soma region', 'max soma', 'total soma', 'max axon']

# %%
import ast
from scipy.spatial.distance import pdist, squareform
import numpy as np
import matplotlib as mpl
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt

def normalize(df, log=True):
    scaled_data = np.array(df) / np.sum(df, axis=0).values.reshape(-1,1) * 100000
    if log:
        scaled_data = np.log(scaled_data+100)
    scaled_dataDF = pd.DataFrame(scaled_data, index=df.index, columns=df.columns)
    return scaled_dataDF

def fromSOMAtoAXON(ns):
    somaDF = ns.features['soma_features'].region
    axonDF = ns.features['projection_features'].raw_data
    normaF=0

    somaregionDF = somaDF.copy()
    axonregionDF = axonDF.copy()      

    colname = ['Cluster Num','soma Region List','axon Region List']

    typeR, typeC = np.unique(ns.metadata['Cluster'] , return_counts = True)
    detailDF = pd.DataFrame(index = typeR,columns = ['swc list','soma region','max soma','total soma',
                                                             'max axon'])

        # for each cluster result UNDER EACH PARAMETER
    somaCLUSTERlist = []
    axonCLUSTERlist = []

    #axonCLUSTER = pd.DataFrame(index = axonregionDF.columns[:-1])
    for label_idx in detailDF.index:
        axonTEMPdf = pd.DataFrame(index = axonregionDF.columns)
        swcINlabel = ns.metadata[ns.metadata['Cluster']==label_idx]
        detailDF.loc[label_idx,'swc list'] = (swcINlabel.index).tolist()
        #assert(len(inter_list)==somaDF[somaDF['cluster'] !=label_idx].shape[0])
        detailDF.loc[label_idx,'soma region'] = swcINlabel['SomaRegion'].tolist()
        del_soma_region = detailDF.loc[label_idx,'soma region']
        while 'unknown' in del_soma_region:
            del_soma_region.remove('unknown')
            del_soma_region.append('others')
        while 'fiber tracts' in del_soma_region:
            del_soma_region.remove('fiber tracts')
            del_soma_region.append('others')
        IDrange, IDcounts = np.unique(del_soma_region, return_counts = True)
        #sort the counting
        count_sort_ind = np.argsort(-IDcounts)
        dicitem = []
        for i in range(1,min(len(IDrange)+1,4)):
            dicitem.append(str(i)+'somaR')
        for i in range(1,min(len(IDrange)+1,4)):
            dicitem.append(str(i)+'somaC')
        #select the first three regions
        dicvalue = IDrange[count_sort_ind][0:min(3,len(IDrange))]
        dicvalue = np.append(dicvalue,IDcounts[count_sort_ind][0:min(3,len(IDrange))])
        detailDF.loc[label_idx,'max soma'] = str(dict(zip(dicitem, dicvalue)))
        detailDF.loc[label_idx,'total soma'] = swcINlabel.shape[0]

        #axonLABEL stores all the rows under same cluster
        axonregionDF.loc[:,'cluster'] = ns.metadata['Cluster'].copy()
        axonLABEL = axonregionDF[axonregionDF['cluster']==label_idx].copy()
        axonLABEL.drop('cluster', axis=1,inplace=True)
        axonTEMPdf[label_idx]=axonLABEL.sum()
        if 'contra_fiber tracts' in axonTEMPdf.index:
            axonTEMPdf.drop(index=['contra_fiber tracts'],inplace = True)
        if 'ipsi_fiber tracts' in axonTEMPdf.index:
            axonTEMPdf.drop(index=['ipsi_fiber tracts'],inplace = True)
        if normaF:
            #normalize the sum
            axonTEMPdf = normalize(axonTEMPdf , log=True)
        axonTEMPdf.sort_values(by=label_idx, ascending=False, inplace=True)
        dicitem = []
        for i in range(1,5):
            dicitem.append(str(i)+'axonR')
        for i in range(1,5):
            dicitem.append(str(i)+'axonC')

        dicvalue = axonTEMPdf.index[:3]
        dicvalue = np.append(dicvalue, 'other')
        dicvalue = np.append(dicvalue,axonTEMPdf.loc[:,label_idx][:3])
        dicvalue = np.append(dicvalue,sum(axonTEMPdf.loc[:,label_idx][:-1])-sum(axonTEMPdf.loc[:,label_idx][:3]))
        detailDF.loc[label_idx,'max axon'] = str(dict(zip(dicitem, dicvalue)))
        axonCLUSTERlist.append(detailDF.loc[label_idx,'max axon'] )
    #(detailDF).to_csv('/home/penglab/Documents/detailXie.csv')
    clusterDF = detailDF.copy()
    dfname=[]
    for cluster_idx in clusterDF.index:
        dfname.append((str(cluster_idx) + 'DF'))

    #generate a dataframe for each cluster
    dicDF = {k:None for k in dfname}

    #iterate the correponding dataframe and cluster at the same time
    for key_iter,cluster_idx in zip(dicDF.keys(),clusterDF.index):
        dic_soma = ast.literal_eval(clusterDF.loc[cluster_idx,'max soma'])
        iterL = int(len(dic_soma.keys())/2)
        somaNAME = []
        somaCOUNT = []

        for i in range(1,int(iterL)+1):
            somaNAME.append(dic_soma[(str(i)+'somaR')])
        for i in range(1,iterL+1):
            somaCOUNT.append(dic_soma[str(i)+'somaC'])
        somaArr = np.array(somaCOUNT, dtype = float)
        somaArr = somaArr/sum(somaArr)
        dic_axon = ast.literal_eval(clusterDF.loc[cluster_idx,'max axon'])
        iterL = int(len(dic_axon.keys())/2)
        axonNAME = []
        axonCOUNT = []
        for i in range(1,iterL+1):
            axonNAME.append(dic_axon[(str(i)+'axonR')])
        for i in range(1,iterL+1):
            axonCOUNT.append(dic_axon[str(i)+'axonC']) 

        tempDF = pd.DataFrame()
        for row_soma in somaNAME:
            for col_axon,len_axon in zip(axonNAME,axonCOUNT):
                tempDF.loc[row_soma, col_axon] = len_axon

        assert(tempDF.shape[0] == len(somaArr))  
        tempDF=tempDF.astype(float)
        for i in range(tempDF.shape[0]):
            tempDF.iloc[i,:] = tempDF.iloc[i,:]*somaArr[i].copy()

        newDF = pd.DataFrame(columns=['from','to','value'],index=range(tempDF.shape[0]*tempDF.shape[1]))
        newDF.loc[:,'from'] = (tempDF.index).tolist()*len(tempDF.columns)
        newDF.loc[:,'to'] = [ele for ele in (tempDF.columns).tolist() for _ in range(len(tempDF.index))]
        valuelist=[]
        for iter_col in tempDF.columns:
            for iter_row in tempDF.index:
                valuelist.append(tempDF.loc[iter_row,iter_col])
        newDF.loc[:,'value']=valuelist
        dicDF[key_iter]= newDF.copy()
    return dicDF

# %%
dicXie = fromSOMAtoAXON(ns_xie)

# %%
for iter_key in dicXie.keys():
    tempDF = dicXie[iter_key]
    print(tempDF)
    (tempDF).to_csv('/home/penglab/Documents/Sep12hier/'+str(iter_key)+'.csv')
# Out:
#     from        to         value
# 0    MOs  ipsi_VAL  4.215519e+05
# 1   ACAd  ipsi_VAL  5.928074e+04
# 2    MOp  ipsi_VAL  3.293374e+04
# 3    MOs   ipsi_MD  3.638318e+05
# 4   ACAd   ipsi_MD  5.116385e+04
# 5    MOp   ipsi_MD  2.842436e+04
# 6    MOs   ipsi_VM  3.145437e+05
# 7   ACAd   ipsi_VM  4.423271e+04
# 8    MOp   ipsi_VM  2.457373e+04
# 9    MOs     other  2.448362e+06
# 10  ACAd     other  3.443009e+05
# 11   MOp     other  1.912783e+05
#    from           to          value
# 0   VAL     ipsi_MOp  322810.711843
# 1    CL     ipsi_MOp  129124.284737
# 2    VM     ipsi_MOp  129124.284737
# 3   VAL     ipsi_MOs  312009.338672
# 4    CL     ipsi_MOs  124803.735469
# 5    VM     ipsi_MOs  124803.735469
# 6   VAL  ipsi_SSp-ul  145073.964962
# 7    CL  ipsi_SSp-ul   58029.585985
# 8    VM  ipsi_SSp-ul   58029.585985
# 9   VAL        other  639332.269052
# 10   CL        other  255732.907621
# 11   VM        other  255732.907621
#     from        to          value
# 0    SUB  ipsi_SUB  160072.422068
# 1    CA1  ipsi_SUB   73879.579416
# 2   ProS  ipsi_SUB   36939.789708
# 3    SUB   ipsi_AV  156823.951629
# 4    CA1   ipsi_AV   72380.285367
# 5   ProS   ipsi_AV   36190.142684
# 6    SUB  ipsi_CA1  143756.168835
# 7    CA1  ipsi_CA1   66349.001001
# 8   ProS  ipsi_CA1   33174.500500
# 9    SUB     other  689120.802809
# 10   CA1     other  318055.755142
# 11  ProS     other  159027.877571
#       from         to         value
# 0      MOs   ipsi_MOs  1.023461e+06
# 1     ACAd   ipsi_MOs  4.548716e+05
# 2   others   ipsi_MOs  2.274358e+05
# 3      MOs  ipsi_ACAd  4.619034e+05
# 4     ACAd  ipsi_ACAd  2.052904e+05
# 5   others  ipsi_ACAd  1.026452e+05
# 6      MOs    ipsi_CP  2.913767e+05
# 7     ACAd    ipsi_CP  1.295008e+05
# 8   others    ipsi_CP  6.475039e+04
# 9      MOs      other  9.934059e+05
# 10    ACAd      other  4.415137e+05
# 11  others      other  2.207569e+05
#       from         to          value
# 0      SUB  ipsi_ENTm  184124.874911
# 1   others  ipsi_ENTm   96907.828901
# 2      PRE  ipsi_ENTm   77526.263121
# 3      SUB   ipsi_SUB  163563.691407
# 4   others   ipsi_SUB   86086.153372
# 5      PRE   ipsi_SUB   68868.922697
# 6      SUB  ipsi_POST  131286.523503
# 7   others  ipsi_POST   69098.170265
# 8      PRE  ipsi_POST   55278.536212
# 9      SUB      other  693480.235233
# 10  others      other  364989.597491
# 11     PRE      other  291991.677993
#     from           to          value
# 0    PRE  contra_ENTm  422313.376453
# 1   POST  contra_ENTm  117854.895754
# 2     DG  contra_ENTm   58927.447877
# 3    PRE    ipsi_ENTm  363042.446822
# 4   POST    ipsi_ENTm  101314.171206
# 5     DG    ipsi_ENTm   50657.085603
# 6    PRE  contra_ENTl  147359.126739
# 7   POST  contra_ENTl   41123.477229
# 8     DG  contra_ENTl   20561.738615
# 9    PRE        other  510613.230371
# 10  POST        other  142496.715452
# 11    DG        other   71248.357726
#       from        to         value
# 0   others  ipsi_PAG  2.825337e+05
# 1       ZI  ipsi_PAG  1.569632e+05
# 2      LHA  ipsi_PAG  9.417791e+04
# 3   others  ipsi_MRN  2.390710e+05
# 4       ZI  ipsi_MRN  1.328172e+05
# 5      LHA  ipsi_MRN  7.969035e+04
# 6   others  ipsi_SCm  1.401112e+05
# 7       ZI  ipsi_SCm  7.783956e+04
# 8      LHA  ipsi_SCm  4.670374e+04
# 9   others     other  1.047669e+06
# 10      ZI     other  5.820384e+05
# 11     LHA     other  3.492231e+05
#       from        to         value
# 0   others  ipsi_LSr  9.169706e+04
# 1       MM  ipsi_LSr  3.667882e+04
# 2      LHA  ipsi_LSr  2.750912e+04
# 3   others  ipsi_LHA  6.153116e+04
# 4       MM  ipsi_LHA  2.461246e+04
# 5      LHA  ipsi_LHA  1.845935e+04
# 6   others  ipsi_IRN  4.837686e+04
# 7       MM  ipsi_IRN  1.935074e+04
# 8      LHA  ipsi_IRN  1.451306e+04
# 9   others     other  1.701930e+06
# 10      MM     other  6.807720e+05
# 11     LHA     other  5.105790e+05
#     from         to          value
# 0    SUB  ipsi_RSPv  269325.821664
# 1   ProS  ipsi_RSPv  127575.389209
# 2     AV  ipsi_RSPv   99225.302718
# 3    SUB    ipsi_MM  105880.167842
# 4   ProS    ipsi_MM   50153.763715
# 5     AV    ipsi_MM   39008.482889
# 6    SUB   ipsi_SUB   92369.160076
# 7   ProS   ipsi_SUB   43753.812668
# 8     AV   ipsi_SUB   34030.743186
# 9    SUB      other  734292.377034
# 10  ProS      other  347822.704911
# 11    AV      other  270528.770486
#    from          to          value
# 0    DG    ipsi_CA1  386978.366743
# 1   CA3    ipsi_CA1  113817.166689
# 2   CA1    ipsi_CA1   91053.733351
# 3    DG     ipsi_DG  178024.978594
# 4   CA3     ipsi_DG   52360.287822
# 5   CA1     ipsi_DG   41888.230257
# 6    DG  contra_CA1  129413.840572
# 7   CA3  contra_CA1   38062.894286
# 8   CA1  contra_CA1   30450.315429
# 9    DG       other  245542.088514
# 10  CA3       other   72218.261328
# 11  CA1       other   57774.609062
#       from         to          value
# 0       DG   ipsi_CA3  176149.755592
# 1      CA3   ipsi_CA3    7658.685026
# 2   others   ipsi_CA3    7658.685026
# 3       DG    ipsi_DG  134343.545049
# 4      CA3    ipsi_DG    5841.023698
# 5   others    ipsi_DG    5841.023698
# 6       DG  contra_DG  133513.662110
# 7      CA3  contra_DG    5804.941831
# 8   others  contra_DG    5804.941831
# 9       DG      other   56249.179701
# 10     CA3      other    2445.616509
# 11  others      other    2445.616509

# %%
detailDF
# Out:
#                                              swc list  \
# 1   [17302_00021, 17302_00053, 17545_00110, 17545_...
# 2   [17545_00003, 18454_00065, 18457_00099, 18457_...
# 3   [17302_00020, 17302_00054, 17545_00071, 18454_...
# 4   [17302_00113, 17545_00055, 17545_00056, 17545_...
# 5   [17302_00078, 17302_00112, 17302_00114, 17302_...
# 6   [17545_00081, 17545_00163, 17545_00164, 17545_...
# 7   [17302_00035, 17302_00036, 17302_00038, 17302_...
# 8   [17302_00034, 17302_00039, 17302_00040, 17302_...
# 9   [17302_00080, 17302_00117, 17545_00088, 17545_...
# 10  [17545_00089, 18454_00128, 18458_00075, 18458_...
# 11  [17302_00037, 17545_00162, 17545_00169, 17545_...
# 12  [17302_00001, 17302_00002, 17302_00003, 17302_...
# 13  [18454_00009, 18457_00007, 18457_00008, 18457_...
# 14  [17302_00075, 17545_00026, 17545_00029, 17545_...
# 15  [17302_00014, 17302_00015, 17302_00016, 17302_...
# 16  [17302_00023, 17302_00024, 17302_00025, 18454_...
# 17  [17302_00017, 17302_00099, 17545_00028, 17545_...
# 18                         [18454_00002, 18457_00075]
# 19  [17302_00013, 17302_00081, 17302_00085, 17302_...
# 20  [17302_00018, 17302_00043, 17545_00001, 17545_...
# 21  [17545_00115, 17545_00144, 18454_00022, 18457_...
# 22  [17302_00030, 17302_00033, 17302_00050, 17302_...
# 23  [17302_00046, 17302_00047, 17302_00055, 17302_...
# 24  [17302_00032, 17302_00102, 17545_00047, 17545_...
# 25  [17302_00044, 17302_00045, 17302_00105, 17302_...
#
#                                           soma region  \
# 1   [VPL, VPM, VPM, VPM, RT, RT, VPL, others, others]
# 2                            [LD, RT, others, others]
# 3           [VPL, VPM, PO, VPM, VPM, BST, LD, others]
# 4   [LGv, VPM, RT, RT, LD, RT, RT, RT, others, oth...
# 5   [LGd, LGv, IGL, LGd, LGd, others, others, othe...
# 6                        [LGd, CA3, CA3, CA3, others]
# 7   [MG, CA3, MG, LGd, LGd, CA3, LGd, LP, DG, DG, ...
# 8   [CA3, CA3, CA3, CA3, CA3, CA3, CA3, CA3, CA3, ...
# 9   [CA3, CA3, CA3, CA3, CA3, LGd, CA3, CA3, other...
# 10                 [LGd, LGd, LD, DG, LP, LP, others]
# 11                            [IGL, LGd, LGd, others]
# 12  [AId, AId, GU, GU, GU, GU, GU, SSs, SSs, SSp-m...
# 13  [MOp, AId, AId, ORBl, others, others, others, ...
# 14                          [GU, SSs, SSs, CP, SSp-m]
# 15  [SSp-m, SSs, SSp-m, SSp-m, SSs, GU, SSs, SSp-m...
# 16                 [AM, PVT, MD, SMT, MD, MD, others]
# 17                        [VISC, TEa, others, others]
# 18                                      [LGd, others]
# 19  [SSs, AId, CP, GU, AIv, CLA, AId, CP, AId, CLA...
# 20        [CP, PIR, AIp, CP, AIv, CP, others, others]
# 21            [AIv, GU, CP, SI, OT, ACB, AON, others]
# 22  [AId, CLA, CP, MOp, AId, CP, ORBl, ORBl, ORBl,...
# 23  [SSp-n, SSp-ul, MOp, MOp, MOp, SSp-ll, MOp, SS...
# 24                          [MOp, MOs, MOp, MOp, MOp]
# 25  [MOp, MOp, AId, MOp, MOp, MOp, MOp, MOs, GU, M...
#
#                                              max soma total soma  \
# 1   {'1somaR': 'VPM', '2somaR': 'RT', '3somaR': 'V...          9
# 2   {'1somaR': 'others', '2somaR': 'LD', '3somaR':...          4
# 3   {'1somaR': 'VPM', '2somaR': 'BST', '3somaR': '...          8
# 4   {'1somaR': 'others', '2somaR': 'RT', '3somaR':...         22
# 5   {'1somaR': 'others', '2somaR': 'LGd', '3somaR'...         16
# 6   {'1somaR': 'CA3', '2somaR': 'LGd', '3somaR': '...          5
# 7   {'1somaR': 'DG', '2somaR': 'LGd', '3somaR': 'C...         15
# 8   {'1somaR': 'CA3', '2somaR': 'DG', '3somaR': 'L...         23
# 9   {'1somaR': 'CA3', '2somaR': 'others', '3somaR'...         11
# 10  {'1somaR': 'LGd', '2somaR': 'LP', '3somaR': 'D...          7
# 11  {'1somaR': 'LGd', '2somaR': 'IGL', '3somaR': '...          4
# 12  {'1somaR': 'GU', '2somaR': 'AId', '3somaR': 'C...         27
# 13  {'1somaR': 'others', '2somaR': 'AId', '3somaR'...          8
# 14  {'1somaR': 'SSs', '2somaR': 'CP', '3somaR': 'G...          5
# 15  {'1somaR': 'SSp-m', '2somaR': 'SSs', '3somaR':...         14
# 16  {'1somaR': 'MD', '2somaR': 'AM', '3somaR': 'PV...          7
# 17  {'1somaR': 'others', '2somaR': 'TEa', '3somaR'...          4
# 18  {'1somaR': 'LGd', '2somaR': 'others', '1somaC'...          2
# 19  {'1somaR': 'CP', '2somaR': 'AId', '3somaR': 'C...         15
# 20  {'1somaR': 'CP', '2somaR': 'others', '3somaR':...          8
# 21  {'1somaR': 'ACB', '2somaR': 'AIv', '3somaR': '...          8
# 22  {'1somaR': 'CP', '2somaR': 'others', '3somaR':...         28
# 23  {'1somaR': 'MOp', '2somaR': 'SSp-ul', '3somaR'...         11
# 24  {'1somaR': 'MOp', '2somaR': 'MOs', '1somaC': '...          5
# 25  {'1somaR': 'MOp', '2somaR': 'MOs', '3somaR': '...         18
#
#                                              max axon
# 1   {'1axonR': 'ipsi_SSp-m', '2axonR': 'ipsi_SSs',...
# 2   {'1axonR': 'ipsi_SSp-ul', '2axonR': 'ipsi_CP',...
# 3   {'1axonR': 'ipsi_MOp', '2axonR': 'ipsi_MOs', '...
# 4   {'1axonR': 'ipsi_SSp-bfd', '2axonR': 'ipsi_SSp...
# 5   {'1axonR': 'ipsi_SSp-bfd', '2axonR': 'ipsi_CP'...
# 6   {'1axonR': 'ipsi_AUDp', '2axonR': 'ipsi_AUDv',...
# 7   {'1axonR': 'ipsi_AUDp', '2axonR': 'ipsi_TEa', ...
# 8   {'1axonR': 'ipsi_VISp', '2axonR': 'ipsi_RSPagl...
# 9   {'1axonR': 'ipsi_VISp', '2axonR': 'ipsi_RSPagl...
# 10  {'1axonR': 'ipsi_VISam', '2axonR': 'ipsi_RSPag...
# 11  {'1axonR': 'ipsi_SSs', '2axonR': 'ipsi_VISp', ...
# 12  {'1axonR': 'ipsi_SNr', '2axonR': 'ipsi_CP', '3...
# 13  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_SNr', '3...
# 14  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_SSp-m', ...
# 15  {'1axonR': 'ipsi_SSp-m', '2axonR': 'ipsi_CP', ...
# 16  {'1axonR': 'ipsi_ORBl', '2axonR': 'ipsi_AId', ...
# 17  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_VISC', '...
# 18  {'1axonR': 'ipsi_GPe', '2axonR': 'ipsi_CP', '3...
# 19  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_AId', '3...
# 20  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_AIv', '3...
# 21  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_SI', '3a...
# 22  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_ORBl', '...
# 23  {'1axonR': 'ipsi_SSp-ul', '2axonR': 'ipsi_CP',...
# 24  {'1axonR': 'ipsi_MOp', '2axonR': 'ipsi_MOs', '...
# 25  {'1axonR': 'ipsi_MOp', '2axonR': 'ipsi_CP', '3...

# %%
ns = example_[0]
somaDF = ns.features['soma_features'].region
axonDF = ns.features['projection_features'].raw_data
normaF=0

somaregionDF = somaDF.copy()
axonregionDF = axonDF.copy()      

colname = ['Cluster Num','soma Region List','axon Region List']

typeR, typeC = np.unique(ns.metadata['Cluster'] , return_counts = True)
detailDF = pd.DataFrame(index = typeR,columns = ['swc list','soma region','max soma','total soma',
                                                         'max axon'])

    # for each cluster result UNDER EACH PARAMETER
somaCLUSTERlist = []
axonCLUSTERlist = []

#axonCLUSTER = pd.DataFrame(index = axonregionDF.columns[:-1])
for label_idx in detailDF.index:
    axonTEMPdf = pd.DataFrame(index = axonregionDF.columns)
    swcINlabel = ns.metadata[ns.metadata['Cluster']==label_idx]
    detailDF.loc[label_idx,'swc list'] = (swcINlabel.index).tolist()
    #assert(len(inter_list)==somaDF[somaDF['cluster'] !=label_idx].shape[0])
    detailDF.loc[label_idx,'soma region'] = swcINlabel['SomaRegion'].tolist()
    del_soma_region = detailDF.loc[label_idx,'soma region']
    while 'unknown' in del_soma_region:
        del_soma_region.remove('unknown')
        del_soma_region.append('others')
    while 'fiber tracts' in del_soma_region:
        del_soma_region.remove('fiber tracts')
        del_soma_region.append('others')
    IDrange, IDcounts = np.unique(del_soma_region, return_counts = True)
    #sort the counting
    count_sort_ind = np.argsort(-IDcounts)
    dicitem = []
    for i in range(1,min(len(IDrange)+1,4)):
        dicitem.append(str(i)+'somaR')
    for i in range(1,min(len(IDrange)+1,4)):
        dicitem.append(str(i)+'somaC')
    #select the first three regions
    dicvalue = IDrange[count_sort_ind][0:min(3,len(IDrange))]
    dicvalue = np.append(dicvalue,IDcounts[count_sort_ind][0:min(3,len(IDrange))])
    detailDF.loc[label_idx,'max soma'] = str(dict(zip(dicitem, dicvalue)))
    detailDF.loc[label_idx,'total soma'] = swcINlabel.shape[0]

    #axonLABEL stores all the rows under same cluster
    axonregionDF.loc[:,'cluster'] = ns.metadata['Cluster'].copy()
    axonLABEL = axonregionDF[axonregionDF['cluster']==label_idx].copy()
    axonLABEL.drop('cluster', axis=1,inplace=True)
    axonTEMPdf[label_idx]=axonLABEL.sum()
    if 'contra_fiber tracts' in axonTEMPdf.index:
        axonTEMPdf.drop(index=['contra_fiber tracts'],inplace = True)
    if 'ipsi_fiber tracts' in axonTEMPdf.index:
        axonTEMPdf.drop(index=['ipsi_fiber tracts'],inplace = True)
    if normaF:
        #normalize the sum
        axonTEMPdf = normalize(axonTEMPdf , log=True)
    axonTEMPdf.sort_values(by=label_idx, ascending=False, inplace=True)
    dicitem = []
    for i in range(1,5):
        dicitem.append(str(i)+'axonR')
    for i in range(1,5):
        dicitem.append(str(i)+'axonC')

    dicvalue = axonTEMPdf.index[:3]
    dicvalue = np.append(dicvalue, 'others')
    dicvalue = np.append(dicvalue,axonTEMPdf.loc[:,label_idx][:3])
    dicvalue = np.append(dicvalue,sum(axonTEMPdf.loc[:,label_idx][:-1])-sum(axonTEMPdf.loc[:,label_idx][:3]))
    detailDF.loc[label_idx,'max axon'] = str(dict(zip(dicitem, dicvalue)))
    axonCLUSTERlist.append(detailDF.loc[label_idx,'max axon'] )
#(detailDF).to_csv('/home/penglab/Documents/detailXie.csv')
clusterDF = detailDF.copy()

# %%
clusterDF
# Out:
#                                              swc list  \
# 1   [17302_00021, 17302_00053, 17545_00110, 17545_...
# 2   [17545_00003, 18454_00065, 18457_00099, 18457_...
# 3   [17302_00020, 17302_00054, 17545_00071, 18454_...
# 4   [17302_00113, 17545_00055, 17545_00056, 17545_...
# 5   [17302_00078, 17302_00112, 17302_00114, 17302_...
# 6   [17545_00081, 17545_00163, 17545_00164, 17545_...
# 7   [17302_00035, 17302_00036, 17302_00038, 17302_...
# 8   [17302_00034, 17302_00039, 17302_00040, 17302_...
# 9   [17302_00080, 17302_00117, 17545_00088, 17545_...
# 10  [17545_00089, 18454_00128, 18458_00075, 18458_...
# 11  [17302_00037, 17545_00162, 17545_00169, 17545_...
# 12  [17302_00001, 17302_00002, 17302_00003, 17302_...
# 13  [18454_00009, 18457_00007, 18457_00008, 18457_...
# 14  [17302_00075, 17545_00026, 17545_00029, 17545_...
# 15  [17302_00014, 17302_00015, 17302_00016, 17302_...
# 16  [17302_00023, 17302_00024, 17302_00025, 18454_...
# 17  [17302_00017, 17302_00099, 17545_00028, 17545_...
# 18                         [18454_00002, 18457_00075]
# 19  [17302_00013, 17302_00081, 17302_00085, 17302_...
# 20  [17302_00018, 17302_00043, 17545_00001, 17545_...
# 21  [17545_00115, 17545_00144, 18454_00022, 18457_...
# 22  [17302_00030, 17302_00033, 17302_00050, 17302_...
# 23  [17302_00046, 17302_00047, 17302_00055, 17302_...
# 24  [17302_00032, 17302_00102, 17545_00047, 17545_...
# 25  [17302_00044, 17302_00045, 17302_00105, 17302_...
#
#                                           soma region  \
# 1   [VPL, VPM, VPM, VPM, RT, RT, VPL, others, others]
# 2                            [LD, RT, others, others]
# 3           [VPL, VPM, PO, VPM, VPM, BST, LD, others]
# 4   [LGv, VPM, RT, RT, LD, RT, RT, RT, others, oth...
# 5   [LGd, LGv, IGL, LGd, LGd, others, others, othe...
# 6                        [LGd, CA3, CA3, CA3, others]
# 7   [MG, CA3, MG, LGd, LGd, CA3, LGd, LP, DG, DG, ...
# 8   [CA3, CA3, CA3, CA3, CA3, CA3, CA3, CA3, CA3, ...
# 9   [CA3, CA3, CA3, CA3, CA3, LGd, CA3, CA3, other...
# 10                 [LGd, LGd, LD, DG, LP, LP, others]
# 11                            [IGL, LGd, LGd, others]
# 12  [AId, AId, GU, GU, GU, GU, GU, SSs, SSs, SSp-m...
# 13  [MOp, AId, AId, ORBl, others, others, others, ...
# 14                          [GU, SSs, SSs, CP, SSp-m]
# 15  [SSp-m, SSs, SSp-m, SSp-m, SSs, GU, SSs, SSp-m...
# 16                 [AM, PVT, MD, SMT, MD, MD, others]
# 17                        [VISC, TEa, others, others]
# 18                                      [LGd, others]
# 19  [SSs, AId, CP, GU, AIv, CLA, AId, CP, AId, CLA...
# 20        [CP, PIR, AIp, CP, AIv, CP, others, others]
# 21            [AIv, GU, CP, SI, OT, ACB, AON, others]
# 22  [AId, CLA, CP, MOp, AId, CP, ORBl, ORBl, ORBl,...
# 23  [SSp-n, SSp-ul, MOp, MOp, MOp, SSp-ll, MOp, SS...
# 24                          [MOp, MOs, MOp, MOp, MOp]
# 25  [MOp, MOp, AId, MOp, MOp, MOp, MOp, MOs, GU, M...
#
#                                              max soma total soma  \
# 1   {'1somaR': 'VPM', '2somaR': 'RT', '3somaR': 'V...          9
# 2   {'1somaR': 'others', '2somaR': 'LD', '3somaR':...          4
# 3   {'1somaR': 'VPM', '2somaR': 'BST', '3somaR': '...          8
# 4   {'1somaR': 'others', '2somaR': 'RT', '3somaR':...         22
# 5   {'1somaR': 'others', '2somaR': 'LGd', '3somaR'...         16
# 6   {'1somaR': 'CA3', '2somaR': 'LGd', '3somaR': '...          5
# 7   {'1somaR': 'DG', '2somaR': 'LGd', '3somaR': 'C...         15
# 8   {'1somaR': 'CA3', '2somaR': 'DG', '3somaR': 'L...         23
# 9   {'1somaR': 'CA3', '2somaR': 'others', '3somaR'...         11
# 10  {'1somaR': 'LGd', '2somaR': 'LP', '3somaR': 'D...          7
# 11  {'1somaR': 'LGd', '2somaR': 'IGL', '3somaR': '...          4
# 12  {'1somaR': 'GU', '2somaR': 'AId', '3somaR': 'C...         27
# 13  {'1somaR': 'others', '2somaR': 'AId', '3somaR'...          8
# 14  {'1somaR': 'SSs', '2somaR': 'CP', '3somaR': 'G...          5
# 15  {'1somaR': 'SSp-m', '2somaR': 'SSs', '3somaR':...         14
# 16  {'1somaR': 'MD', '2somaR': 'AM', '3somaR': 'PV...          7
# 17  {'1somaR': 'others', '2somaR': 'TEa', '3somaR'...          4
# 18  {'1somaR': 'LGd', '2somaR': 'others', '1somaC'...          2
# 19  {'1somaR': 'CP', '2somaR': 'AId', '3somaR': 'C...         15
# 20  {'1somaR': 'CP', '2somaR': 'others', '3somaR':...          8
# 21  {'1somaR': 'ACB', '2somaR': 'AIv', '3somaR': '...          8
# 22  {'1somaR': 'CP', '2somaR': 'others', '3somaR':...         28
# 23  {'1somaR': 'MOp', '2somaR': 'SSp-ul', '3somaR'...         11
# 24  {'1somaR': 'MOp', '2somaR': 'MOs', '1somaC': '...          5
# 25  {'1somaR': 'MOp', '2somaR': 'MOs', '3somaR': '...         18
#
#                                              max axon
# 1   {'1axonR': 'ipsi_SSp-m', '2axonR': 'ipsi_SSs',...
# 2   {'1axonR': 'ipsi_SSp-ul', '2axonR': 'ipsi_CP',...
# 3   {'1axonR': 'ipsi_MOp', '2axonR': 'ipsi_MOs', '...
# 4   {'1axonR': 'ipsi_SSp-bfd', '2axonR': 'ipsi_SSp...
# 5   {'1axonR': 'ipsi_SSp-bfd', '2axonR': 'ipsi_CP'...
# 6   {'1axonR': 'ipsi_AUDp', '2axonR': 'ipsi_AUDv',...
# 7   {'1axonR': 'ipsi_AUDp', '2axonR': 'ipsi_TEa', ...
# 8   {'1axonR': 'ipsi_VISp', '2axonR': 'ipsi_RSPagl...
# 9   {'1axonR': 'ipsi_VISp', '2axonR': 'ipsi_RSPagl...
# 10  {'1axonR': 'ipsi_VISam', '2axonR': 'ipsi_RSPag...
# 11  {'1axonR': 'ipsi_SSs', '2axonR': 'ipsi_VISp', ...
# 12  {'1axonR': 'ipsi_SNr', '2axonR': 'ipsi_CP', '3...
# 13  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_SNr', '3...
# 14  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_SSp-m', ...
# 15  {'1axonR': 'ipsi_SSp-m', '2axonR': 'ipsi_CP', ...
# 16  {'1axonR': 'ipsi_ORBl', '2axonR': 'ipsi_AId', ...
# 17  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_VISC', '...
# 18  {'1axonR': 'ipsi_GPe', '2axonR': 'ipsi_CP', '3...
# 19  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_AId', '3...
# 20  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_AIv', '3...
# 21  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_SI', '3a...
# 22  {'1axonR': 'ipsi_CP', '2axonR': 'ipsi_ORBl', '...
# 23  {'1axonR': 'ipsi_SSp-ul', '2axonR': 'ipsi_CP',...
# 24  {'1axonR': 'ipsi_MOp', '2axonR': 'ipsi_MOs', '...
# 25  {'1axonR': 'ipsi_MOp', '2axonR': 'ipsi_CP', '3...

# %%
dfname=[]
for cluster_idx in clusterDF.index:
    dfname.append((str(cluster_idx) + 'DF'))

#generate a dataframe for each cluster
dicDF = {k:None for k in dfname}

#iterate the correponding dataframe and cluster at the same time
for key_iter,cluster_idx in zip(dicDF.keys(),clusterDF.index):
    dic_soma = ast.literal_eval(clusterDF.loc[cluster_idx,'max soma'])
    iterL = int(len(dic_soma.keys())/2)
    somaNAME = []
    somaCOUNT = []

    for i in range(1,int(iterL)+1):
        somaNAME.append(dic_soma[(str(i)+'somaR')])
    for i in range(1,iterL+1):
        somaCOUNT.append(dic_soma[str(i)+'somaC'])
    somaArr = np.array(somaCOUNT, dtype = float)
    somaArr = somaArr/sum(somaArr)
    dic_axon = ast.literal_eval(clusterDF.loc[cluster_idx,'max axon'])
    iterL = int(len(dic_axon.keys())/2)
    axonNAME = []
    axonCOUNT = []
    for i in range(1,iterL+1):
        axonNAME.append(dic_axon[(str(i)+'axonR')])
    for i in range(1,iterL+1):
        axonCOUNT.append(dic_axon[str(i)+'axonC']) 
    tempDF = pd.DataFrame()
    for row_soma in somaNAME:
        for col_axon,len_axon in zip(axonNAME,axonCOUNT):
            tempDF.loc[row_soma, col_axon] = len_axon


    assert(tempDF.shape[0] == len(somaArr))  
    tempDF=tempDF.astype(float)
    for i in range(tempDF.shape[0]):
        tempDF.iloc[i,:] = tempDF.iloc[i,:]*somaArr[i].copy()

# %%
tempDF
# Out:
#              ipsi_MOp        ipsi_CP    ipsi_SSp-m        others
# MOp     143012.912185  109284.298845  29043.349090  48921.527412
# MOs      23835.485364   18214.049808   4840.558182   8153.587902
# others   23835.485364   18214.049808   4840.558182   8153.587902

# %%
len(tempDF.columns)
# Out:
# 4

# %%
newDF = pd.DataFrame(columns=['from','to','value'],index=range(tempDF.shape[0]*tempDF.shape[1]))
newDF.loc[:,'from'] = (tempDF.index).tolist()*len(tempDF.columns)
newDF.loc[:,'to'] = [ele for ele in (tempDF.columns).tolist() for _ in range(len(tempDF.index))]
newDF
# Out:
#       from          to value
# 0      MOp    ipsi_MOp   NaN
# 1      MOs    ipsi_MOp   NaN
# 2   others    ipsi_MOp   NaN
# 3      MOp     ipsi_CP   NaN
# 4      MOs     ipsi_CP   NaN
# 5   others     ipsi_CP   NaN
# 6      MOp  ipsi_SSp-m   NaN
# 7      MOs  ipsi_SSp-m   NaN
# 8   others  ipsi_SSp-m   NaN
# 9      MOp      others   NaN
# 10     MOs      others   NaN
# 11  others      others   NaN

# %%
somaArr
# Out:
# array([0.75 , 0.125, 0.125])
