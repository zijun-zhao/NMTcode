# %%
import numpy as np
import pandas as pd
import os
from shutil import copyfile
import pickle
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import colorlover as cl


import neuro_morpho_toolbox as nmt
# %matplotlib inline
# Out:
# /home/penglab/anaconda3/lib/python3.7/site-packages/neuro_morpho_toolbox-0.1-py3.7.egg/neuro_morpho_toolbox/
# Loading CCF Atlas data...
# Loading time: 0.78
# Loading CCF brain structure data...
# Loading time: 0.00
# Loading selected CCF Atlas and Contour data...
# Loading time: 0.91

# %%
region_all, count = np.unique(mergeRlist, return_counts=True)
len(region_all)
# Out:
# 7

# %%
mergeRlist =  nmt.mergeROI([315,1089,703,672,549,1097], nmt.annotation.array)
# Out:
# Merging child region Isocortex into region Isocortex
# Merging child region FRP into region Isocortex
# Merging child region FRP1 into region Isocortex
# Merging child region FRP2/3 into region Isocortex
# Merging child region FRP5 into region Isocortex
# Merging child region FRP6a into region Isocortex
# Merging child region FRP6b into region Isocortex
# Merging child region MO into region Isocortex
# Merging child region MO1 into region Isocortex
# Merging child region MO2/3 into region Isocortex
# Merging child region MO5 into region Isocortex
# Merging child region MO6a into region Isocortex
# Merging child region MO6b into region Isocortex
# Merging child region MOp into region Isocortex
# Merging child region MOp1 into region Isocortex
# Merging child region MOp2/3 into region Isocortex
# Merging child region MOp5 into region Isocortex
# Merging child region MOp6a into region Isocortex
# Merging child region MOp6b into region Isocortex
# Merging child region MOs into region Isocortex
# Merging child region MOs1 into region Isocortex
# Merging child region MOs2/3 into region Isocortex
# Merging child region MOs5 into region Isocortex
# Merging child region MOs6a into region Isocortex
# Merging child region MOs6b into region Isocortex
# Merging child region SS into region Isocortex
# Merging child region SS1 into region Isocortex
# Merging child region SS2/3 into region Isocortex
# Merging child region SS4 into region Isocortex
# Merging child region SS5 into region Isocortex
# Merging child region SS6a into region Isocortex
# Merging child region SS6b into region Isocortex
# Merging child region SSp into region Isocortex
# Merging child region SSp1 into region Isocortex
# Merging child region SSp2/3 into region Isocortex
# Merging child region SSp4 into region Isocortex
# Merging child region SSp5 into region Isocortex
# Merging child region SSp6a into region Isocortex
# Merging child region SSp6b into region Isocortex
# Merging child region SSp-n into region Isocortex
# Merging child region SSp-n1 into region Isocortex
# Merging child region SSp-n2/3 into region Isocortex
# Merging child region SSp-n4 into region Isocortex
# Merging child region SSp-n5 into region Isocortex
# Merging child region SSp-n6a into region Isocortex
# Merging child region SSp-n6b into region Isocortex
# Merging child region SSp-bfd into region Isocortex
# Merging child region SSp-bfd1 into region Isocortex
# Merging child region SSp-bfd2/3 into region Isocortex
# Merging child region SSp-bfd4 into region Isocortex
# Merging child region SSp-bfd5 into region Isocortex
# Merging child region SSp-bfd6a into region Isocortex
# Merging child region SSp-bfd6b into region Isocortex
# Merging child region VISrll into region Isocortex
# Merging child region VISrll1 into region Isocortex
# Merging child region VISrll2/3 into region Isocortex
# Merging child region VISrll4 into region Isocortex
# Merging child region VISrll5 into region Isocortex
# Merging child region VISrll6a into region Isocortex
# Merging child region VISrll6b into region Isocortex
# Merging child region SSp-ll into region Isocortex
# Merging child region SSp-ll1 into region Isocortex
# Merging child region SSp-ll2/3 into region Isocortex
# Merging child region SSp-ll4 into region Isocortex
# Merging child region SSp-ll5 into region Isocortex
# Merging child region SSp-ll6a into region Isocortex
# Merging child region SSp-ll6b into region Isocortex
# Merging child region SSp-m into region Isocortex
# Merging child region SSp-m1 into region Isocortex
# Merging child region SSp-m2/3 into region Isocortex
# Merging child region SSp-m4 into region Isocortex
# Merging child region SSp-m5 into region Isocortex
# Merging child region SSp-m6a into region Isocortex
# Merging child region SSp-m6b into region Isocortex
# Merging child region SSp-ul into region Isocortex
# Merging child region SSp-ul1 into region Isocortex
# Merging child region SSp-ul2/3 into region Isocortex
# Merging child region SSp-ul4 into region Isocortex
# Merging child region SSp-ul5 into region Isocortex
# Merging child region SSp-ul6a into region Isocortex
# Merging child region SSp-ul6b into region Isocortex
# Merging child region SSp-tr into region Isocortex
# Merging child region SSp-tr1 into region Isocortex
# Merging child region SSp-tr2/3 into region Isocortex
# Merging child region SSp-tr4 into region Isocortex
# Merging child region SSp-tr5 into region Isocortex
# Merging child region SSp-tr6a into region Isocortex
# Merging child region SSp-tr6b into region Isocortex
# Merging child region SSp-un into region Isocortex
# Merging child region SSp-un1 into region Isocortex
# Merging child region SSp-un2/3 into region Isocortex
# Merging child region SSp-un4 into region Isocortex
# Merging child region SSp-un5 into region Isocortex
# Merging child region SSp-un6a into region Isocortex
# Merging child region SSp-un6b into region Isocortex
# Merging child region SSs into region Isocortex
# Merging child region SSs1 into region Isocortex
# Merging child region SSs2/3 into region Isocortex
# Merging child region SSs4 into region Isocortex
# Merging child region SSs5 into region Isocortex
# Merging child region SSs6a into region Isocortex
# Merging child region SSs6b into region Isocortex
# Merging child region GU into region Isocortex
# Merging child region GU1 into region Isocortex
# Merging child region GU2/3 into region Isocortex
# Merging child region GU4 into region Isocortex
# Merging child region GU5 into region Isocortex
# Merging child region GU6a into region Isocortex
# Merging child region GU6b into region Isocortex
# Merging child region VISC into region Isocortex
# Merging child region VISC1 into region Isocortex
# Merging child region VISC2/3 into region Isocortex
# Merging child region VISC4 into region Isocortex
# Merging child region VISC5 into region Isocortex
# Merging child region VISC6a into region Isocortex
# Merging child region VISC6b into region Isocortex
# Merging child region AUD into region Isocortex
# Merging child region AUDd into region Isocortex
# Merging child region AUDd1 into region Isocortex
# Merging child region AUDd2/3 into region Isocortex
# Merging child region AUDd4 into region Isocortex
# Merging child region AUDd5 into region Isocortex
# Merging child region AUDd6a into region Isocortex
# Merging child region AUDd6b into region Isocortex
# Merging child region VISlla into region Isocortex
# Merging child region VISlla1 into region Isocortex
# Merging child region VISlla2/3 into region Isocortex
# Merging child region VISlla4 into region Isocortex
# Merging child region VISlla5 into region Isocortex
# Merging child region VISlla6a into region Isocortex
# Merging child region VISlla6b into region Isocortex
# Merging child region AUDp into region Isocortex
# Merging child region AUDp1 into region Isocortex
# Merging child region AUDp2/3 into region Isocortex
# Merging child region AUDp4 into region Isocortex
# Merging child region AUDp5 into region Isocortex
# Merging child region AUDp6a into region Isocortex
# Merging child region AUDp6b into region Isocortex
# Merging child region AUDpo into region Isocortex
# Merging child region AUDpo1 into region Isocortex
# Merging child region AUDpo2/3 into region Isocortex
# Merging child region AUDpo4 into region Isocortex
# Merging child region AUDpo5 into region Isocortex
# Merging child region AUDpo6a into region Isocortex
# Merging child region AUDpo6b into region Isocortex
# Merging child region AUDv into region Isocortex
# Merging child region AUDv1 into region Isocortex
# Merging child region AUDv2/3 into region Isocortex
# Merging child region AUDv4 into region Isocortex
# Merging child region AUDv5 into region Isocortex
# Merging child region AUDv6a into region Isocortex
# Merging child region AUDv6b into region Isocortex
# Merging child region VIS into region Isocortex
# Merging child region VIS1 into region Isocortex
# Merging child region VIS2/3 into region Isocortex
# Merging child region VIS4 into region Isocortex
# Merging child region VIS5 into region Isocortex
# Merging child region VIS6a into region Isocortex
# Merging child region VIS6b into region Isocortex
# Merging child region VISal into region Isocortex
# Merging child region VISal1 into region Isocortex
# Merging child region VISal2/3 into region Isocortex
# Merging child region VISal4 into region Isocortex
# Merging child region VISal5 into region Isocortex
# Merging child region VISal6a into region Isocortex
# Merging child region VISal6b into region Isocortex
# Merging child region VISam into region Isocortex
# Merging child region VISam1 into region Isocortex
# Merging child region VISam2/3 into region Isocortex
# Merging child region VISam4 into region Isocortex
# Merging child region VISam5 into region Isocortex
# Merging child region VISam6a into region Isocortex
# Merging child region VISam6b into region Isocortex
# Merging child region VISl into region Isocortex
# Merging child region VISl1 into region Isocortex
# Merging child region VISl2/3 into region Isocortex
# Merging child region VISl4 into region Isocortex
# Merging child region VISl5 into region Isocortex
# Merging child region VISl6a into region Isocortex
# Merging child region VISl6b into region Isocortex
# Merging child region VISp into region Isocortex
# Merging child region VISp1 into region Isocortex
# Merging child region VISp2/3 into region Isocortex
# Merging child region VISp4 into region Isocortex
# Merging child region VISp5 into region Isocortex
# Merging child region VISp6a into region Isocortex
# Merging child region VISp6b into region Isocortex
# Merging child region VISpl into region Isocortex
# Merging child region VISpl1 into region Isocortex
# Merging child region VISpl2/3 into region Isocortex
# Merging child region VISpl4 into region Isocortex
# Merging child region VISpl5 into region Isocortex
# Merging child region VISpl6a into region Isocortex
# Merging child region VISpl6b into region Isocortex
# Merging child region VISpm into region Isocortex
# Merging child region VISpm1 into region Isocortex
# Merging child region VISpm2/3 into region Isocortex
# Merging child region VISpm4 into region Isocortex
# Merging child region VISpm5 into region Isocortex
# Merging child region VISpm6a into region Isocortex
# Merging child region VISpm6b into region Isocortex
# Merging child region VISli into region Isocortex
# Merging child region VISli1 into region Isocortex
# Merging child region VISli2/3 into region Isocortex
# Merging child region VISli4 into region Isocortex
# Merging child region VISli5 into region Isocortex
# Merging child region VISli6a into region Isocortex
# Merging child region VISli6b into region Isocortex
# Merging child region VISpor into region Isocortex
# Merging child region VISpor1 into region Isocortex
# Merging child region VISpor2/3 into region Isocortex
# Merging child region VISpor4 into region Isocortex
# Merging child region VISpor5 into region Isocortex
# Merging child region VISpor6a into region Isocortex
# Merging child region VISpor6b into region Isocortex
# Merging child region ACA into region Isocortex
# Merging child region ACA1 into region Isocortex
# Merging child region ACA2/3 into region Isocortex
# Merging child region ACA5 into region Isocortex
# Merging child region ACA6a into region Isocortex
# Merging child region ACA6b into region Isocortex
# Merging child region ACAd into region Isocortex
# Merging child region ACAd1 into region Isocortex
# Merging child region ACAd2/3 into region Isocortex
# Merging child region ACAd5 into region Isocortex
# Merging child region ACAd6a into region Isocortex
# Merging child region ACAd6b into region Isocortex
# Merging child region ACAv into region Isocortex
# Merging child region ACAv1 into region Isocortex
# Merging child region ACAv2/3 into region Isocortex
# Merging child region ACAv5 into region Isocortex
# Merging child region ACAv6a into region Isocortex
# Merging child region ACAv6b into region Isocortex
# Merging child region PL into region Isocortex
# Merging child region PL1 into region Isocortex
# Merging child region PL2 into region Isocortex
# Merging child region PL2/3 into region Isocortex
# Merging child region PL5 into region Isocortex
# Merging child region PL6a into region Isocortex
# Merging child region PL6b into region Isocortex
# Merging child region ILA into region Isocortex
# Merging child region ILA1 into region Isocortex
# Merging child region ILA2 into region Isocortex
# Merging child region ILA2/3 into region Isocortex
# Merging child region ILA5 into region Isocortex
# Merging child region ILA6a into region Isocortex
# Merging child region ILA6b into region Isocortex
# Merging child region ORB into region Isocortex
# Merging child region ORB1 into region Isocortex
# Merging child region ORB2/3 into region Isocortex
# Merging child region ORB5 into region Isocortex
# Merging child region ORB6a into region Isocortex
# Merging child region ORB6b into region Isocortex
# Merging child region ORBl into region Isocortex
# Merging child region ORBl1 into region Isocortex
# Merging child region ORBl2/3 into region Isocortex
# Merging child region ORBl5 into region Isocortex
# Merging child region ORBl6a into region Isocortex
# Merging child region ORBl6b into region Isocortex
# Merging child region ORBm into region Isocortex
# Merging child region ORBm1 into region Isocortex
# Merging child region ORBm2 into region Isocortex
# Merging child region ORBm2/3 into region Isocortex
# Merging child region ORBm5 into region Isocortex
# Merging child region ORBm6a into region Isocortex
# Merging child region ORBm6b into region Isocortex
# Merging child region ORBv into region Isocortex
# Merging child region ORBvl into region Isocortex
# Merging child region ORBvl1 into region Isocortex
# Merging child region ORBvl2/3 into region Isocortex
# Merging child region ORBvl5 into region Isocortex
# Merging child region ORBvl6a into region Isocortex
# Merging child region ORBvl6b into region Isocortex
# Merging child region AI into region Isocortex
# Merging child region AId into region Isocortex
# Merging child region AId1 into region Isocortex
# Merging child region AId2/3 into region Isocortex
# Merging child region AId5 into region Isocortex
# Merging child region AId6a into region Isocortex
# Merging child region AId6b into region Isocortex
# Merging child region AIp into region Isocortex
# Merging child region AIp1 into region Isocortex
# Merging child region AIp2/3 into region Isocortex
# Merging child region AIp5 into region Isocortex
# Merging child region AIp6a into region Isocortex
# Merging child region AIp6b into region Isocortex
# Merging child region AIv into region Isocortex
# Merging child region AIv1 into region Isocortex
# Merging child region AIv2/3 into region Isocortex
# Merging child region AIv5 into region Isocortex
# Merging child region AIv6a into region Isocortex
# Merging child region AIv6b into region Isocortex
# Merging child region RSP into region Isocortex
# Merging child region RSPagl into region Isocortex
# Merging child region RSPagl1 into region Isocortex
# Merging child region RSPagl2/3 into region Isocortex
# Merging child region RSPagl5 into region Isocortex
# Merging child region RSPagl6a into region Isocortex
# Merging child region RSPagl6b into region Isocortex
# Merging child region VISmma into region Isocortex
# Merging child region VISmma1 into region Isocortex
# Merging child region VISmma2/3 into region Isocortex
# Merging child region VISmma4 into region Isocortex
# Merging child region VISmma5 into region Isocortex
# Merging child region VISmma6a into region Isocortex
# Merging child region VISmma6b into region Isocortex
# Merging child region VISmmp into region Isocortex
# Merging child region VISmmp1 into region Isocortex
# Merging child region VISmmp2/3 into region Isocortex
# Merging child region VISmmp4 into region Isocortex
# Merging child region VISmmp5 into region Isocortex
# Merging child region VISmmp6a into region Isocortex
# Merging child region VISmmp6b into region Isocortex
# Merging child region VISm into region Isocortex
# Merging child region VISm1 into region Isocortex
# Merging child region VISm2/3 into region Isocortex
# Merging child region VISm4 into region Isocortex
# Merging child region VISm5 into region Isocortex
# Merging child region VISm6a into region Isocortex
# Merging child region VISm6b into region Isocortex
# Merging child region RSPd into region Isocortex
# Merging child region RSPd1 into region Isocortex
# Merging child region RSPd2/3 into region Isocortex
# Merging child region RSPd4 into region Isocortex
# Merging child region RSPd5 into region Isocortex
# Merging child region RSPd6a into region Isocortex
# Merging child region RSPd6b into region Isocortex
# Merging child region RSPv into region Isocortex
# Merging child region RSPv1 into region Isocortex
# Merging child region RSPv2 into region Isocortex
# Merging child region RSPv2/3 into region Isocortex
# Merging child region RSPv5 into region Isocortex
# Merging child region RSPv6a into region Isocortex
# Merging child region RSPv6b into region Isocortex
# Merging child region PTLp into region Isocortex
# Merging child region PTLp1 into region Isocortex
# Merging child region PTLp2/3 into region Isocortex
# Merging child region PTLp4 into region Isocortex
# Merging child region PTLp5 into region Isocortex
# Merging child region PTLp6a into region Isocortex
# Merging child region PTLp6b into region Isocortex
# Merging child region VISa into region Isocortex
# Merging child region VISa1 into region Isocortex
# Merging child region VISa2/3 into region Isocortex
# Merging child region VISa4 into region Isocortex
# Merging child region VISa5 into region Isocortex
# Merging child region VISa6a into region Isocortex
# Merging child region VISa6b into region Isocortex
# Merging child region VISrl into region Isocortex
# Merging child region VISrl1 into region Isocortex
# Merging child region VISrl2/3 into region Isocortex
# Merging child region VISrl4 into region Isocortex
# Merging child region VISrl5 into region Isocortex
# Merging child region VISrl6a into region Isocortex
# Merging child region VISrl6b into region Isocortex
# Merging child region TEa into region Isocortex
# Merging child region TEa1 into region Isocortex
# Merging child region TEa2/3 into region Isocortex
# Merging child region TEa4 into region Isocortex
# Merging child region TEa5 into region Isocortex
# Merging child region TEa6a into region Isocortex
# Merging child region TEa6b into region Isocortex
# Merging child region PERI into region Isocortex
# Merging child region PERI6a into region Isocortex
# Merging child region PERI6b into region Isocortex
# Merging child region PERI1 into region Isocortex
# Merging child region PERI5 into region Isocortex
# Merging child region PERI2/3 into region Isocortex
# Merging child region ECT into region Isocortex
# Merging child region ECT1 into region Isocortex
# Merging child region ECT2/3 into region Isocortex
# Merging child region ECT5 into region Isocortex
# Merging child region ECT6a into region Isocortex
# Merging child region ECT6b into region Isocortex
# Loading time for region Isocortex : 157.34
# Merging child region HPF into region HPF
# Merging child region HIP into region HPF
# Merging child region CA into region HPF
# Merging child region CA1 into region HPF
# Merging child region CA1slm into region HPF
# Merging child region CA1so into region HPF
# Merging child region CA1sp into region HPF
# Merging child region CA1sr into region HPF
# Merging child region CA2 into region HPF
# Merging child region CA2slm into region HPF
# Merging child region CA2so into region HPF
# Merging child region CA2sp into region HPF
# Merging child region CA2sr into region HPF
# Merging child region CA3 into region HPF
# Merging child region CA3slm into region HPF
# Merging child region CA3slu into region HPF
# Merging child region CA3so into region HPF
# Merging child region CA3sp into region HPF
# Merging child region CA3sr into region HPF
# Merging child region DG into region HPF
# Merging child region DG-mo into region HPF
# Merging child region DG-po into region HPF
# Merging child region DG-sg into region HPF
# Merging child region DG-sgz into region HPF
# Merging child region DGcr into region HPF
# Merging child region DGcr-mo into region HPF
# Merging child region DGcr-po into region HPF
# Merging child region DGcr-sg into region HPF
# Merging child region DGlb into region HPF
# Merging child region DGlb-mo into region HPF
# Merging child region DGlb-po into region HPF
# Merging child region DGlb-sg into region HPF
# Merging child region DGmb into region HPF
# Merging child region DGmb-mo into region HPF
# Merging child region DGmb-po into region HPF
# Merging child region DGmb-sg into region HPF
# Merging child region FC into region HPF
# Merging child region IG into region HPF
# Merging child region RHP into region HPF
# Merging child region ENT into region HPF
# Merging child region ENTl into region HPF
# Merging child region ENTl1 into region HPF
# Merging child region ENTl2 into region HPF
# Merging child region ENTl2/3 into region HPF
# Merging child region ENTl2a into region HPF
# Merging child region ENTl2b into region HPF
# Merging child region ENTl3 into region HPF
# Merging child region ENTl4 into region HPF
# Merging child region ENTl4/5 into region HPF
# Merging child region ENTl5 into region HPF
# Merging child region ENTl5/6 into region HPF
# Merging child region ENTl6a into region HPF
# Merging child region ENTl6b into region HPF
# Merging child region ENTm into region HPF
# Merging child region ENTm1 into region HPF
# Merging child region ENTm2 into region HPF
# Merging child region ENTm2a into region HPF
# Merging child region ENTm2b into region HPF
# Merging child region ENTm3 into region HPF
# Merging child region ENTm4 into region HPF
# Merging child region ENTm5 into region HPF
# Merging child region ENTm5/6 into region HPF
# Merging child region ENTm6 into region HPF
# Merging child region ENTmv into region HPF
# Merging child region ENTmv1 into region HPF
# Merging child region ENTmv2 into region HPF
# Merging child region ENTmv3 into region HPF
# Merging child region ENTmv4 into region HPF
# Merging child region ENTmv5/6 into region HPF
# Merging child region PAR into region HPF
# Merging child region PAR1 into region HPF
# Merging child region PAR2 into region HPF
# Merging child region PAR3 into region HPF
# Merging child region POST into region HPF
# Merging child region POST1 into region HPF
# Merging child region POST2 into region HPF
# Merging child region POST3 into region HPF
# Merging child region PRE into region HPF
# Merging child region PRE1 into region HPF
# Merging child region PRE2 into region HPF
# Merging child region PRE3 into region HPF
# Merging child region SUB into region HPF
# Merging child region SUBd into region HPF
# Merging child region SUBd-m into region HPF
# Merging child region SUBd-sp into region HPF
# Merging child region SUBd-sr into region HPF
# Merging child region SUBv into region HPF
# Merging child region SUBv-m into region HPF
# Merging child region SUBv-sp into region HPF
# Merging child region SUBv-sr into region HPF
# Merging child region ProS into region HPF
# Merging child region ProSd into region HPF
# Merging child region ProSd-m into region HPF
# Merging child region ProSd-sp into region HPF
# Merging child region ProSd-sr into region HPF
# Merging child region ProSv into region HPF
# Merging child region ProSv-m into region HPF
# Merging child region ProSv-sp into region HPF
# Merging child region Prosv-sr into region HPF
# Merging child region HATA into region HPF
# Merging child region APr into region HPF
# Loading time for region HPF : 43.11
# Merging child region CTXsp into region CTXsp
# Merging child region 6b into region CTXsp
# Merging child region CLA into region CTXsp
# Merging child region EP into region CTXsp
# Merging child region EPd into region CTXsp
# Merging child region EPv into region CTXsp
# Merging child region LA into region CTXsp
# Merging child region BLA into region CTXsp
# Merging child region BLAa into region CTXsp
# Merging child region BLAp into region CTXsp
# Merging child region BLAv into region CTXsp
# Merging child region BMA into region CTXsp
# Merging child region BMAa into region CTXsp
# Merging child region BMAp into region CTXsp
# Merging child region PA into region CTXsp
# Loading time for region CTXsp : 6.35
# Merging child region CP into region CP
# Loading time for region CP : 0.45
# Merging child region TH into region TH
# Merging child region DORsm into region TH
# Merging child region VENT into region TH
# Merging child region VAL into region TH
# Merging child region VM into region TH
# Merging child region VP into region TH
# Merging child region VPL into region TH
# Merging child region VPLpc into region TH
# Merging child region VPM into region TH
# Merging child region VPMpc into region TH
# Merging child region PoT into region TH
# Merging child region SPF into region TH
# Merging child region SPFm into region TH
# Merging child region SPFp into region TH
# Merging child region SPA into region TH
# Merging child region PP into region TH
# Merging child region GENd into region TH
# Merging child region MG into region TH
# Merging child region MGd into region TH
# Merging child region MGv into region TH
# Merging child region MGm into region TH
# Merging child region LGd into region TH
# Merging child region LGd-sh into region TH
# Merging child region LGd-co into region TH
# Merging child region LGd-ip into region TH
# Merging child region DORpm into region TH
# Merging child region LAT into region TH
# Merging child region LP into region TH
# Merging child region PO into region TH
# Merging child region POL into region TH
# Merging child region SGN into region TH
# Merging child region Eth into region TH
# Merging child region REth into region TH
# Merging child region ATN into region TH
# Merging child region AV into region TH
# Merging child region AM into region TH
# Merging child region AMd into region TH
# Merging child region AMv into region TH
# Merging child region AD into region TH
# Merging child region IAM into region TH
# Merging child region IAD into region TH
# Merging child region LD into region TH
# Merging child region MED into region TH
# Merging child region IMD into region TH
# Merging child region MD into region TH
# Merging child region MDc into region TH
# Merging child region MDl into region TH
# Merging child region MDm into region TH
# Merging child region SMT into region TH
# Merging child region PR into region TH
# Merging child region MTN into region TH
# Merging child region PVT into region TH
# Merging child region PT into region TH
# Merging child region RE into region TH
# Merging child region Xi into region TH
# Merging child region ILM into region TH
# Merging child region RH into region TH
# Merging child region CM into region TH
# Merging child region PCN into region TH
# Merging child region CL into region TH
# Merging child region PF into region TH
# Merging child region PIL into region TH
# Merging child region RT into region TH
# Merging child region GENv into region TH
# Merging child region IGL into region TH
# Merging child region IntG into region TH
# Merging child region LGv into region TH
# Merging child region LGvl into region TH
# Merging child region LGvm into region TH
# Merging child region SubG into region TH
# Merging child region EPI into region TH
# Merging child region MH into region TH
# Merging child region LH into region TH
# Merging child region PIN into region TH
# Loading time for region TH : 31.38
# Merging child region HY into region HY
# Merging child region PVZ into region HY
# Merging child region SO into region HY
# Merging child region ASO into region HY
# Merging child region NC into region HY
# Merging child region PVH into region HY
# Merging child region PVHm into region HY
# Merging child region PVHam into region HY
# Merging child region PVHmm into region HY
# Merging child region PVHpm into region HY
# Merging child region PVHpml into region HY
# Merging child region PVHpmm into region HY
# Merging child region PVHp into region HY
# Merging child region PVHap into region HY
# Merging child region PVHmpd into region HY
# Merging child region PVHpv into region HY
# Merging child region PVa into region HY
# Merging child region PVi into region HY
# Merging child region ARH into region HY
# Merging child region PVR into region HY
# Merging child region ADP into region HY
# Merging child region AHA into region HY
# Merging child region AVP into region HY
# Merging child region AVPV into region HY
# Merging child region DMH into region HY
# Merging child region DMHa into region HY
# Merging child region DMHp into region HY
# Merging child region DMHv into region HY
# Merging child region MEPO into region HY
# Merging child region MPO into region HY
# Merging child region OV into region HY
# Merging child region PD into region HY
# Merging child region PS into region HY
# Merging child region PSCH into region HY
# Merging child region PVp into region HY
# Merging child region PVpo into region HY
# Merging child region SBPV into region HY
# Merging child region SCH into region HY
# Merging child region SFO into region HY
# Merging child region VMPO into region HY
# Merging child region VLPO into region HY
# Merging child region MEZ into region HY
# Merging child region AHN into region HY
# Merging child region AHNa into region HY
# Merging child region AHNc into region HY
# Merging child region AHNd into region HY
# Merging child region AHNp into region HY
# Merging child region MBO into region HY
# Merging child region LM into region HY
# Merging child region MM into region HY
# Merging child region Mmme into region HY
# Merging child region Mml into region HY
# Merging child region Mmm into region HY
# Merging child region Mmp into region HY
# Merging child region Mmd into region HY
# Merging child region SUM into region HY
# Merging child region SUMl into region HY
# Merging child region SUMm into region HY
# Merging child region TM into region HY
# Merging child region TMd into region HY
# Merging child region TMv into region HY
# Merging child region MPN into region HY
# Merging child region MPNc into region HY
# Merging child region MPNl into region HY
# Merging child region MPNm into region HY
# Merging child region PMd into region HY
# Merging child region PMv into region HY
# Merging child region PVHd into region HY
# Merging child region PVHdp into region HY
# Merging child region PVHf into region HY
# Merging child region PVHlp into region HY
# Merging child region PVHmpv into region HY
# Merging child region VMH into region HY
# Merging child region VMHa into region HY
# Merging child region VMHc into region HY
# Merging child region VMHdm into region HY
# Merging child region VMHvl into region HY
# Merging child region PH into region HY
# Merging child region LZ into region HY
# Merging child region LHA into region HY
# Merging child region LPO into region HY
# Merging child region PST into region HY
# Merging child region PSTN into region HY
# Merging child region PeF into region HY
# Merging child region RCH into region HY
# Merging child region STN into region HY
# Merging child region TU into region HY
# Merging child region ZI into region HY
# Merging child region A13 into region HY
# Merging child region FF into region HY
# Merging child region ME into region HY
# Loading time for region HY : 37.08

# %%
mergeccf =  nmt.mergeROI(nmt.bs.selected_regions, nmt.annotation.array)
# Out:
# Merging child region FRP into region FRP
# Merging child region FRP1 into region FRP
# Merging child region FRP2/3 into region FRP
# Merging child region FRP5 into region FRP
# Merging child region FRP6a into region FRP
# Merging child region FRP6b into region FRP
# Loading time for region FRP : 2.52
# Merging child region MOp into region MOp
# Merging child region MOp1 into region MOp
# Merging child region MOp2/3 into region MOp
# Merging child region MOp5 into region MOp
# Merging child region MOp6a into region MOp
# Merging child region MOp6b into region MOp
# Loading time for region MOp : 2.46
# Merging child region MOs into region MOs
# Merging child region MOs1 into region MOs
# Merging child region MOs2/3 into region MOs
# Merging child region MOs5 into region MOs
# Merging child region MOs6a into region MOs
# Merging child region MOs6b into region MOs
# Loading time for region MOs : 2.38
# Merging child region SSp-n into region SSp-n
# Merging child region SSp-n1 into region SSp-n
# Merging child region SSp-n2/3 into region SSp-n
# Merging child region SSp-n4 into region SSp-n
# Merging child region SSp-n5 into region SSp-n
# Merging child region SSp-n6a into region SSp-n
# Merging child region SSp-n6b into region SSp-n
# Loading time for region SSp-n : 2.76
# Merging child region SSp-bfd into region SSp-bfd
# Merging child region SSp-bfd1 into region SSp-bfd
# Merging child region SSp-bfd2/3 into region SSp-bfd
# Merging child region SSp-bfd4 into region SSp-bfd
# Merging child region SSp-bfd5 into region SSp-bfd
# Merging child region SSp-bfd6a into region SSp-bfd
# Merging child region SSp-bfd6b into region SSp-bfd
# Merging child region VISrll into region SSp-bfd
# Merging child region VISrll1 into region SSp-bfd
# Merging child region VISrll2/3 into region SSp-bfd
# Merging child region VISrll4 into region SSp-bfd
# Merging child region VISrll5 into region SSp-bfd
# Merging child region VISrll6a into region SSp-bfd
# Merging child region VISrll6b into region SSp-bfd
# Loading time for region SSp-bfd : 5.55
# Merging child region SSp-ll into region SSp-ll
# Merging child region SSp-ll1 into region SSp-ll
# Merging child region SSp-ll2/3 into region SSp-ll
# Merging child region SSp-ll4 into region SSp-ll
# Merging child region SSp-ll5 into region SSp-ll
# Merging child region SSp-ll6a into region SSp-ll
# Merging child region SSp-ll6b into region SSp-ll
# Loading time for region SSp-ll : 2.75
# Merging child region SSp-m into region SSp-m
# Merging child region SSp-m1 into region SSp-m
# Merging child region SSp-m2/3 into region SSp-m
# Merging child region SSp-m4 into region SSp-m
# Merging child region SSp-m5 into region SSp-m
# Merging child region SSp-m6a into region SSp-m
# Merging child region SSp-m6b into region SSp-m
# Loading time for region SSp-m : 2.77
# Merging child region SSp-ul into region SSp-ul
# Merging child region SSp-ul1 into region SSp-ul
# Merging child region SSp-ul2/3 into region SSp-ul
# Merging child region SSp-ul4 into region SSp-ul
# Merging child region SSp-ul5 into region SSp-ul
# Merging child region SSp-ul6a into region SSp-ul
# Merging child region SSp-ul6b into region SSp-ul
# Loading time for region SSp-ul : 2.90
# Merging child region SSp-tr into region SSp-tr
# Merging child region SSp-tr1 into region SSp-tr
# Merging child region SSp-tr2/3 into region SSp-tr
# Merging child region SSp-tr4 into region SSp-tr
# Merging child region SSp-tr5 into region SSp-tr
# Merging child region SSp-tr6a into region SSp-tr
# Merging child region SSp-tr6b into region SSp-tr
# Loading time for region SSp-tr : 2.74
# Merging child region SSp-un into region SSp-un
# Merging child region SSp-un1 into region SSp-un
# Merging child region SSp-un2/3 into region SSp-un
# Merging child region SSp-un4 into region SSp-un
# Merging child region SSp-un5 into region SSp-un
# Merging child region SSp-un6a into region SSp-un
# Merging child region SSp-un6b into region SSp-un
# Loading time for region SSp-un : 2.89
# Merging child region SSs into region SSs
# Merging child region SSs1 into region SSs
# Merging child region SSs2/3 into region SSs
# Merging child region SSs4 into region SSs
# Merging child region SSs5 into region SSs
# Merging child region SSs6a into region SSs
# Merging child region SSs6b into region SSs
# Loading time for region SSs : 2.96
# Merging child region GU into region GU
# Merging child region GU1 into region GU
# Merging child region GU2/3 into region GU
# Merging child region GU4 into region GU
# Merging child region GU5 into region GU
# Merging child region GU6a into region GU
# Merging child region GU6b into region GU
# Loading time for region GU : 2.85
# Merging child region VISC into region VISC
# Merging child region VISC1 into region VISC
# Merging child region VISC2/3 into region VISC
# Merging child region VISC4 into region VISC
# Merging child region VISC5 into region VISC
# Merging child region VISC6a into region VISC
# Merging child region VISC6b into region VISC
# Loading time for region VISC : 2.88
# Merging child region AUDd into region AUDd
# Merging child region AUDd1 into region AUDd
# Merging child region AUDd2/3 into region AUDd
# Merging child region AUDd4 into region AUDd
# Merging child region AUDd5 into region AUDd
# Merging child region AUDd6a into region AUDd
# Merging child region AUDd6b into region AUDd
# Merging child region VISlla into region AUDd
# Merging child region VISlla1 into region AUDd
# Merging child region VISlla2/3 into region AUDd
# Merging child region VISlla4 into region AUDd
# Merging child region VISlla5 into region AUDd
# Merging child region VISlla6a into region AUDd
# Merging child region VISlla6b into region AUDd
# Loading time for region AUDd : 5.55
# Merging child region AUDp into region AUDp
# Merging child region AUDp1 into region AUDp
# Merging child region AUDp2/3 into region AUDp
# Merging child region AUDp4 into region AUDp
# Merging child region AUDp5 into region AUDp
# Merging child region AUDp6a into region AUDp
# Merging child region AUDp6b into region AUDp
# Loading time for region AUDp : 2.73
# Merging child region AUDpo into region AUDpo
# Merging child region AUDpo1 into region AUDpo
# Merging child region AUDpo2/3 into region AUDpo
# Merging child region AUDpo4 into region AUDpo
# Merging child region AUDpo5 into region AUDpo
# Merging child region AUDpo6a into region AUDpo
# Merging child region AUDpo6b into region AUDpo
# Loading time for region AUDpo : 2.71
# Merging child region AUDv into region AUDv
# Merging child region AUDv1 into region AUDv
# Merging child region AUDv2/3 into region AUDv
# Merging child region AUDv4 into region AUDv
# Merging child region AUDv5 into region AUDv
# Merging child region AUDv6a into region AUDv
# Merging child region AUDv6b into region AUDv
# Loading time for region AUDv : 2.85
# Merging child region VISal into region VISal
# Merging child region VISal1 into region VISal
# Merging child region VISal2/3 into region VISal
# Merging child region VISal4 into region VISal
# Merging child region VISal5 into region VISal
# Merging child region VISal6a into region VISal
# Merging child region VISal6b into region VISal
# Loading time for region VISal : 2.72
# Merging child region VISam into region VISam
# Merging child region VISam1 into region VISam
# Merging child region VISam2/3 into region VISam
# Merging child region VISam4 into region VISam
# Merging child region VISam5 into region VISam
# Merging child region VISam6a into region VISam
# Merging child region VISam6b into region VISam
# Loading time for region VISam : 2.85
# Merging child region VISl into region VISl
# Merging child region VISl1 into region VISl
# Merging child region VISl2/3 into region VISl
# Merging child region VISl4 into region VISl
# Merging child region VISl5 into region VISl
# Merging child region VISl6a into region VISl
# Merging child region VISl6b into region VISl
# Loading time for region VISl : 2.83
# Merging child region VISp into region VISp
# Merging child region VISp1 into region VISp
# Merging child region VISp2/3 into region VISp
# Merging child region VISp4 into region VISp
# Merging child region VISp5 into region VISp
# Merging child region VISp6a into region VISp
# Merging child region VISp6b into region VISp
# Loading time for region VISp : 2.83
# Merging child region VISpl into region VISpl
# Merging child region VISpl1 into region VISpl
# Merging child region VISpl2/3 into region VISpl
# Merging child region VISpl4 into region VISpl
# Merging child region VISpl5 into region VISpl
# Merging child region VISpl6a into region VISpl
# Merging child region VISpl6b into region VISpl
# Loading time for region VISpl : 2.80
# Merging child region VISpm into region VISpm
# Merging child region VISpm1 into region VISpm
# Merging child region VISpm2/3 into region VISpm
# Merging child region VISpm4 into region VISpm
# Merging child region VISpm5 into region VISpm
# Merging child region VISpm6a into region VISpm
# Merging child region VISpm6b into region VISpm
# Loading time for region VISpm : 2.72
# Merging child region VISli into region VISli
# Merging child region VISli1 into region VISli
# Merging child region VISli2/3 into region VISli
# Merging child region VISli4 into region VISli
# Merging child region VISli5 into region VISli
# Merging child region VISli6a into region VISli
# Merging child region VISli6b into region VISli
# Loading time for region VISli : 2.72
# Merging child region VISpor into region VISpor
# Merging child region VISpor1 into region VISpor
# Merging child region VISpor2/3 into region VISpor
# Merging child region VISpor4 into region VISpor
# Merging child region VISpor5 into region VISpor
# Merging child region VISpor6a into region VISpor
# Merging child region VISpor6b into region VISpor
# Loading time for region VISpor : 2.73
# Merging child region ACAd into region ACAd
# Merging child region ACAd1 into region ACAd
# Merging child region ACAd2/3 into region ACAd
# Merging child region ACAd5 into region ACAd
# Merging child region ACAd6a into region ACAd
# Merging child region ACAd6b into region ACAd
# Loading time for region ACAd : 2.34
# Merging child region ACAv into region ACAv
# Merging child region ACAv1 into region ACAv
# Merging child region ACAv2/3 into region ACAv
# Merging child region ACAv5 into region ACAv
# Merging child region ACAv6a into region ACAv
# Merging child region ACAv6b into region ACAv
# Loading time for region ACAv : 2.36
# Merging child region PL into region PL
# Merging child region PL1 into region PL
# Merging child region PL2 into region PL
# Merging child region PL2/3 into region PL
# Merging child region PL5 into region PL
# Merging child region PL6a into region PL
# Merging child region PL6b into region PL
# Loading time for region PL : 2.74
# Merging child region ILA into region ILA
# Merging child region ILA1 into region ILA
# Merging child region ILA2 into region ILA
# Merging child region ILA2/3 into region ILA
# Merging child region ILA5 into region ILA
# Merging child region ILA6a into region ILA
# Merging child region ILA6b into region ILA
# Loading time for region ILA : 2.73
# Merging child region ORBl into region ORBl
# Merging child region ORBl1 into region ORBl
# Merging child region ORBl2/3 into region ORBl
# Merging child region ORBl5 into region ORBl
# Merging child region ORBl6a into region ORBl
# Merging child region ORBl6b into region ORBl
# Loading time for region ORBl : 2.35
# Merging child region ORBm into region ORBm
# Merging child region ORBm1 into region ORBm
# Merging child region ORBm2 into region ORBm
# Merging child region ORBm2/3 into region ORBm
# Merging child region ORBm5 into region ORBm
# Merging child region ORBm6a into region ORBm
# Merging child region ORBm6b into region ORBm
# Loading time for region ORBm : 2.74
# Merging child region ORBvl into region ORBvl
# Merging child region ORBvl1 into region ORBvl
# Merging child region ORBvl2/3 into region ORBvl
# Merging child region ORBvl5 into region ORBvl
# Merging child region ORBvl6a into region ORBvl
# Merging child region ORBvl6b into region ORBvl
# Loading time for region ORBvl : 2.34
# Merging child region AId into region AId
# Merging child region AId1 into region AId
# Merging child region AId2/3 into region AId
# Merging child region AId5 into region AId
# Merging child region AId6a into region AId
# Merging child region AId6b into region AId
# Loading time for region AId : 2.35
# Merging child region AIp into region AIp
# Merging child region AIp1 into region AIp
# Merging child region AIp2/3 into region AIp
# Merging child region AIp5 into region AIp
# Merging child region AIp6a into region AIp
# Merging child region AIp6b into region AIp
# Loading time for region AIp : 2.35
# Merging child region AIv into region AIv
# Merging child region AIv1 into region AIv
# Merging child region AIv2/3 into region AIv
# Merging child region AIv5 into region AIv
# Merging child region AIv6a into region AIv
# Merging child region AIv6b into region AIv
# Loading time for region AIv : 2.34
# Merging child region RSPagl into region RSPagl
# Merging child region RSPagl1 into region RSPagl
# Merging child region RSPagl2/3 into region RSPagl
# Merging child region RSPagl5 into region RSPagl
# Merging child region RSPagl6a into region RSPagl
# Merging child region RSPagl6b into region RSPagl
# Merging child region VISmma into region RSPagl
# Merging child region VISmma1 into region RSPagl
# Merging child region VISmma2/3 into region RSPagl
# Merging child region VISmma4 into region RSPagl
# Merging child region VISmma5 into region RSPagl
# Merging child region VISmma6a into region RSPagl
# Merging child region VISmma6b into region RSPagl
# Merging child region VISmmp into region RSPagl
# Merging child region VISmmp1 into region RSPagl
# Merging child region VISmmp2/3 into region RSPagl
# Merging child region VISmmp4 into region RSPagl
# Merging child region VISmmp5 into region RSPagl
# Merging child region VISmmp6a into region RSPagl
# Merging child region VISmmp6b into region RSPagl
# Merging child region VISm into region RSPagl
# Merging child region VISm1 into region RSPagl
# Merging child region VISm2/3 into region RSPagl
# Merging child region VISm4 into region RSPagl
# Merging child region VISm5 into region RSPagl
# Merging child region VISm6a into region RSPagl
# Merging child region VISm6b into region RSPagl
# Loading time for region RSPagl : 10.52
# Merging child region RSPd into region RSPd
# Merging child region RSPd1 into region RSPd
# Merging child region RSPd2/3 into region RSPd
# Merging child region RSPd4 into region RSPd
# Merging child region RSPd5 into region RSPd
# Merging child region RSPd6a into region RSPd
# Merging child region RSPd6b into region RSPd
# Loading time for region RSPd : 2.73
# Merging child region RSPv into region RSPv
# Merging child region RSPv1 into region RSPv
# Merging child region RSPv2 into region RSPv
# Merging child region RSPv2/3 into region RSPv
# Merging child region RSPv5 into region RSPv
# Merging child region RSPv6a into region RSPv
# Merging child region RSPv6b into region RSPv
# Loading time for region RSPv : 2.75
# Merging child region VISa into region VISa
# Merging child region VISa1 into region VISa
# Merging child region VISa2/3 into region VISa
# Merging child region VISa4 into region VISa
# Merging child region VISa5 into region VISa
# Merging child region VISa6a into region VISa
# Merging child region VISa6b into region VISa
# Loading time for region VISa : 2.72
# Merging child region VISrl into region VISrl
# Merging child region VISrl1 into region VISrl
# Merging child region VISrl2/3 into region VISrl
# Merging child region VISrl4 into region VISrl
# Merging child region VISrl5 into region VISrl
# Merging child region VISrl6a into region VISrl
# Merging child region VISrl6b into region VISrl
# Loading time for region VISrl : 2.72
# Merging child region TEa into region TEa
# Merging child region TEa1 into region TEa
# Merging child region TEa2/3 into region TEa
# Merging child region TEa4 into region TEa
# Merging child region TEa5 into region TEa
# Merging child region TEa6a into region TEa
# Merging child region TEa6b into region TEa
# Loading time for region TEa : 2.78
# Merging child region PERI into region PERI
# Merging child region PERI6a into region PERI
# Merging child region PERI6b into region PERI
# Merging child region PERI1 into region PERI
# Merging child region PERI5 into region PERI
# Merging child region PERI2/3 into region PERI
# Loading time for region PERI : 2.38
# Merging child region ECT into region ECT
# Merging child region ECT1 into region ECT
# Merging child region ECT2/3 into region ECT
# Merging child region ECT5 into region ECT
# Merging child region ECT6a into region ECT
# Merging child region ECT6b into region ECT
# Loading time for region ECT : 2.34
# Merging child region MOB into region MOB
# Merging child region MOBgl into region MOB
# Merging child region MOBgr into region MOB
# Merging child region MOBipl into region MOB
# Merging child region MOBmi into region MOB
# Merging child region MOBopl into region MOB
# Loading time for region MOB : 2.34
# Merging child region AOB into region AOB
# Merging child region AOBgl into region AOB
# Merging child region AOBgr into region AOB
# Merging child region AOBmi into region AOB
# Loading time for region AOB : 1.56
# Merging child region AON into region AON
# Merging child region AONd into region AON
# Merging child region AONe into region AON
# Merging child region AONl into region AON
# Merging child region AONm into region AON
# Merging child region AONpv into region AON
# Merging child region AON1 into region AON
# Merging child region AON2 into region AON
# Loading time for region AON : 3.13
# Merging child region TT into region TT
# Merging child region TTd into region TT
# Merging child region TTd1-4 into region TT
# Merging child region TTd1 into region TT
# Merging child region TTd2 into region TT
# Merging child region TTd3 into region TT
# Merging child region TTd4 into region TT
# Merging child region TTv into region TT
# Merging child region TTv1-3 into region TT
# Merging child region TTv1 into region TT
# Merging child region TTv2 into region TT
# Merging child region TTv3 into region TT
# Loading time for region TT : 4.67
# Merging child region DP into region DP
# Merging child region DP1 into region DP
# Merging child region DP2 into region DP
# Merging child region DP2/3 into region DP
# Merging child region DP5 into region DP
# Merging child region DP6a into region DP
# Loading time for region DP : 2.34
# Merging child region PIR into region PIR
# Merging child region PIR1-3 into region PIR
# Merging child region PIR1 into region PIR
# Merging child region PIR2 into region PIR
# Merging child region PIR3 into region PIR
# Loading time for region PIR : 2.00
# Merging child region NLOT into region NLOT
# Merging child region NLOT1-3 into region NLOT
# Merging child region NLOT1 into region NLOT
# Merging child region NLOT2 into region NLOT
# Merging child region NLOT3 into region NLOT
# Loading time for region NLOT : 1.95
# Merging child region COAa into region COAa
# Merging child region COAa1 into region COAa
# Merging child region COAa2 into region COAa
# Merging child region COAa3 into region COAa
# Loading time for region COAa : 1.56
# Merging child region COAp into region COAp
# Merging child region COApl into region COAp
# Merging child region COApl1-2 into region COAp
# Merging child region COApl1-3 into region COAp
# Merging child region COApl1 into region COAp
# Merging child region COApl2 into region COAp
# Merging child region COApl3 into region COAp
# Merging child region COApm into region COAp
# Merging child region COApm1-2 into region COAp
# Merging child region COApm1-3 into region COAp
# Merging child region COApm1 into region COAp
# Merging child region COApm2 into region COAp
# Merging child region COApm3 into region COAp
# Loading time for region COAp : 5.07
# Merging child region PAA into region PAA
# Merging child region PAA1-3 into region PAA
# Merging child region PAA1 into region PAA
# Merging child region PAA2 into region PAA
# Merging child region PAA3 into region PAA
# Loading time for region PAA : 1.95
# Merging child region TR into region TR
# Merging child region TR1-3 into region TR
# Merging child region TR1 into region TR
# Merging child region TR2 into region TR
# Merging child region TR3 into region TR
# Loading time for region TR : 1.95
# Merging child region CA1 into region CA1
# Merging child region CA1slm into region CA1
# Merging child region CA1so into region CA1
# Merging child region CA1sp into region CA1
# Merging child region CA1sr into region CA1
# Loading time for region CA1 : 1.99
# Merging child region CA2 into region CA2
# Merging child region CA2slm into region CA2
# Merging child region CA2so into region CA2
# Merging child region CA2sp into region CA2
# Merging child region CA2sr into region CA2
# Loading time for region CA2 : 1.95
# Merging child region CA3 into region CA3
# Merging child region CA3slm into region CA3
# Merging child region CA3slu into region CA3
# Merging child region CA3so into region CA3
# Merging child region CA3sp into region CA3
# Merging child region CA3sr into region CA3
# Loading time for region CA3 : 2.36
# Merging child region DG into region DG
# Merging child region DG-mo into region DG
# Merging child region DG-po into region DG
# Merging child region DG-sg into region DG
# Merging child region DG-sgz into region DG
# Merging child region DGcr into region DG
# Merging child region DGcr-mo into region DG
# Merging child region DGcr-po into region DG
# Merging child region DGcr-sg into region DG
# Merging child region DGlb into region DG
# Merging child region DGlb-mo into region DG
# Merging child region DGlb-po into region DG
# Merging child region DGlb-sg into region DG
# Merging child region DGmb into region DG
# Merging child region DGmb-mo into region DG
# Merging child region DGmb-po into region DG
# Merging child region DGmb-sg into region DG
# Loading time for region DG : 6.65
# Merging child region FC into region FC
# Loading time for region FC : 0.39
# Merging child region IG into region IG
# Loading time for region IG : 0.39
# Merging child region ENTl into region ENTl
# Merging child region ENTl1 into region ENTl
# Merging child region ENTl2 into region ENTl
# Merging child region ENTl2/3 into region ENTl
# Merging child region ENTl2a into region ENTl
# Merging child region ENTl2b into region ENTl
# Merging child region ENTl3 into region ENTl
# Merging child region ENTl4 into region ENTl
# Merging child region ENTl4/5 into region ENTl
# Merging child region ENTl5 into region ENTl
# Merging child region ENTl5/6 into region ENTl
# Merging child region ENTl6a into region ENTl
# Merging child region ENTl6b into region ENTl
# Loading time for region ENTl : 5.10
# Merging child region ENTm into region ENTm
# Merging child region ENTm1 into region ENTm
# Merging child region ENTm2 into region ENTm
# Merging child region ENTm2a into region ENTm
# Merging child region ENTm2b into region ENTm
# Merging child region ENTm3 into region ENTm
# Merging child region ENTm4 into region ENTm
# Merging child region ENTm5 into region ENTm
# Merging child region ENTm5/6 into region ENTm
# Merging child region ENTm6 into region ENTm
# Loading time for region ENTm : 3.90
# Merging child region PAR into region PAR
# Merging child region PAR1 into region PAR
# Merging child region PAR2 into region PAR
# Merging child region PAR3 into region PAR
# Loading time for region PAR : 1.56
# Merging child region POST into region POST
# Merging child region POST1 into region POST
# Merging child region POST2 into region POST
# Merging child region POST3 into region POST
# Loading time for region POST : 1.56
# Merging child region PRE into region PRE
# Merging child region PRE1 into region PRE
# Merging child region PRE2 into region PRE
# Merging child region PRE3 into region PRE
# Loading time for region PRE : 1.56
# Merging child region SUB into region SUB
# Merging child region SUBd into region SUB
# Merging child region SUBd-m into region SUB
# Merging child region SUBd-sp into region SUB
# Merging child region SUBd-sr into region SUB
# Merging child region SUBv into region SUB
# Merging child region SUBv-m into region SUB
# Merging child region SUBv-sp into region SUB
# Merging child region SUBv-sr into region SUB
# Loading time for region SUB : 3.52
# Merging child region ProS into region ProS
# Merging child region ProSd into region ProS
# Merging child region ProSd-m into region ProS
# Merging child region ProSd-sp into region ProS
# Merging child region ProSd-sr into region ProS
# Merging child region ProSv into region ProS
# Merging child region ProSv-m into region ProS
# Merging child region ProSv-sp into region ProS
# Merging child region Prosv-sr into region ProS
# Loading time for region ProS : 3.51
# Merging child region HATA into region HATA
# Loading time for region HATA : 0.39
# Merging child region APr into region APr
# Loading time for region APr : 0.39
# Merging child region CLA into region CLA
# Loading time for region CLA : 0.39
# Merging child region EPd into region EPd
# Loading time for region EPd : 0.40
# Merging child region EPv into region EPv
# Loading time for region EPv : 0.39
# Merging child region LA into region LA
# Loading time for region LA : 0.39
# Merging child region BLA into region BLA
# Merging child region BLAa into region BLA
# Merging child region BLAp into region BLA
# Merging child region BLAv into region BLA
# Loading time for region BLA : 1.57
# Merging child region BMA into region BMA
# Merging child region BMAa into region BMA
# Merging child region BMAp into region BMA
# Loading time for region BMA : 1.17
# Merging child region PA into region PA
# Loading time for region PA : 0.40
# Merging child region CP into region CP
# Loading time for region CP : 0.44
# Merging child region ACB into region ACB
# Loading time for region ACB : 0.40
# Merging child region FS into region FS
# Loading time for region FS : 0.40
# Merging child region OT into region OT
# Merging child region isl into region OT
# Merging child region islm into region OT
# Merging child region OT1-3 into region OT
# Merging child region OT1 into region OT
# Merging child region OT2 into region OT
# Merging child region OT3 into region OT
# Loading time for region OT : 2.74
# Merging child region LSc into region LSc
# Loading time for region LSc : 0.39
# Merging child region LSr into region LSr
# Loading time for region LSr : 0.40
# Merging child region LSv into region LSv
# Loading time for region LSv : 0.39
# Merging child region SF into region SF
# Loading time for region SF : 0.39
# Merging child region SH into region SH
# Loading time for region SH : 0.39
# Merging child region AAA into region AAA
# Loading time for region AAA : 0.39
# Merging child region BA into region BA
# Loading time for region BA : 0.39
# Merging child region CEA into region CEA
# Merging child region CEAc into region CEA
# Merging child region CEAl into region CEA
# Merging child region CEAm into region CEA
# Loading time for region CEA : 1.56
# Merging child region IA into region IA
# Loading time for region IA : 0.39
# Merging child region MEA into region MEA
# Merging child region MEAad into region MEA
# Merging child region MEAav into region MEA
# Merging child region MEApd into region MEA
# Merging child region MEApd-a into region MEA
# Merging child region MEApd-b into region MEA
# Merging child region MEApd-c into region MEA
# Merging child region MEApv into region MEA
# Loading time for region MEA : 3.14
# Merging child region GPe into region GPe
# Loading time for region GPe : 0.40
# Merging child region GPi into region GPi
# Loading time for region GPi : 0.40
# Merging child region SI into region SI
# Loading time for region SI : 0.41
# Merging child region MA into region MA
# Loading time for region MA : 0.40
# Merging child region MS into region MS
# Loading time for region MS : 0.40
# Merging child region NDB into region NDB
# Loading time for region NDB : 0.40
# Merging child region TRS into region TRS
# Loading time for region TRS : 0.40
# Merging child region BST into region BST
# Merging child region BSTa into region BST
# Merging child region BSTal into region BST
# Merging child region BSTam into region BST
# Merging child region BSTdm into region BST
# Merging child region BSTfu into region BST
# Merging child region BSTju into region BST
# Merging child region BSTmg into region BST
# Merging child region BSTov into region BST
# Merging child region BSTrh into region BST
# Merging child region BSTv into region BST
# Merging child region BSTp into region BST
# Merging child region BSTd into region BST
# Merging child region BSTpr into region BST
# Merging child region BSTif into region BST
# Merging child region BSTtr into region BST
# Merging child region BSTse into region BST
# Loading time for region BST : 6.78
# Merging child region BAC into region BAC
# Loading time for region BAC : 0.40
# Merging child region VAL into region VAL
# Loading time for region VAL : 0.40
# Merging child region VM into region VM
# Loading time for region VM : 0.40
# Merging child region VPL into region VPL
# Loading time for region VPL : 0.40
# Merging child region VPLpc into region VPLpc
# Loading time for region VPLpc : 0.41
# Merging child region VPM into region VPM
# Loading time for region VPM : 0.40
# Merging child region VPMpc into region VPMpc
# Loading time for region VPMpc : 0.39
# Merging child region PoT into region PoT
# Loading time for region PoT : 0.40
# Merging child region SPFm into region SPFm
# Loading time for region SPFm : 0.41
# Merging child region SPFp into region SPFp
# Loading time for region SPFp : 0.41
# Merging child region SPA into region SPA
# Loading time for region SPA : 0.40
# Merging child region PP into region PP
# Loading time for region PP : 0.40
# Merging child region MG into region MG
# Merging child region MGd into region MG
# Merging child region MGv into region MG
# Merging child region MGm into region MG
# Loading time for region MG : 1.58
# Merging child region LGd into region LGd
# Merging child region LGd-sh into region LGd
# Merging child region LGd-co into region LGd
# Merging child region LGd-ip into region LGd
# Loading time for region LGd : 1.58
# Merging child region LP into region LP
# Loading time for region LP : 0.40
# Merging child region PO into region PO
# Loading time for region PO : 0.40
# Merging child region POL into region POL
# Loading time for region POL : 0.40
# Merging child region SGN into region SGN
# Loading time for region SGN : 0.40
# Merging child region AV into region AV
# Loading time for region AV : 0.39
# Merging child region AM into region AM
# Merging child region AMd into region AM
# Merging child region AMv into region AM
# Loading time for region AM : 1.18
# Merging child region AD into region AD
# Loading time for region AD : 0.40
# Merging child region IAM into region IAM
# Loading time for region IAM : 0.39
# Merging child region IAD into region IAD
# Loading time for region IAD : 0.39
# Merging child region LD into region LD
# Loading time for region LD : 0.41
# Merging child region IMD into region IMD
# Loading time for region IMD : 0.40
# Merging child region MD into region MD
# Merging child region MDc into region MD
# Merging child region MDl into region MD
# Merging child region MDm into region MD
# Loading time for region MD : 1.57
# Merging child region SMT into region SMT
# Loading time for region SMT : 0.40
# Merging child region PR into region PR
# Loading time for region PR : 0.39
# Merging child region PVT into region PVT
# Loading time for region PVT : 0.40
# Merging child region PT into region PT
# Loading time for region PT : 0.40
# Merging child region RE into region RE
# Loading time for region RE : 0.40
# Merging child region Xi into region Xi
# Loading time for region Xi : 0.40
# Merging child region RH into region RH
# Loading time for region RH : 0.39
# Merging child region CM into region CM
# Loading time for region CM : 0.39
# Merging child region PCN into region PCN
# Loading time for region PCN : 0.39
# Merging child region CL into region CL
# Loading time for region CL : 0.40
# Merging child region PF into region PF
# Loading time for region PF : 0.39
# Merging child region PIL into region PIL
# Loading time for region PIL : 0.40
# Merging child region RT into region RT
# Loading time for region RT : 0.41
# Merging child region IGL into region IGL
# Loading time for region IGL : 0.39
# Merging child region IntG into region IntG
# Loading time for region IntG : 0.40
# Merging child region LGv into region LGv
# Merging child region LGvl into region LGv
# Merging child region LGvm into region LGv
# Loading time for region LGv : 1.17
# Merging child region SubG into region SubG
# Loading time for region SubG : 0.39
# Merging child region MH into region MH
# Loading time for region MH : 0.40
# Merging child region LH into region LH
# Loading time for region LH : 0.40
# Merging child region SO into region SO
# Loading time for region SO : 0.39
# Merging child region ASO into region ASO
# Merging child region NC into region ASO
# Loading time for region ASO : 0.79
# Merging child region PVH into region PVH
# Merging child region PVHm into region PVH
# Merging child region PVHam into region PVH
# Merging child region PVHmm into region PVH
# Merging child region PVHpm into region PVH
# Merging child region PVHpml into region PVH
# Merging child region PVHpmm into region PVH
# Merging child region PVHp into region PVH
# Merging child region PVHap into region PVH
# Merging child region PVHmpd into region PVH
# Merging child region PVHpv into region PVH
# Loading time for region PVH : 4.30
# Merging child region PVa into region PVa
# Loading time for region PVa : 0.39
# Merging child region PVi into region PVi
# Loading time for region PVi : 0.39
# Merging child region ARH into region ARH
# Loading time for region ARH : 0.39
# Merging child region ADP into region ADP
# Loading time for region ADP : 0.39
# Merging child region AVP into region AVP
# Loading time for region AVP : 0.39
# Merging child region AVPV into region AVPV
# Loading time for region AVPV : 0.39
# Merging child region DMH into region DMH
# Merging child region DMHa into region DMH
# Merging child region DMHp into region DMH
# Merging child region DMHv into region DMH
# Loading time for region DMH : 1.56
# Merging child region MEPO into region MEPO
# Loading time for region MEPO : 0.39
# Merging child region MPO into region MPO
# Loading time for region MPO : 0.39
# Merging child region OV into region OV
# Loading time for region OV : 0.39
# Merging child region PD into region PD
# Loading time for region PD : 0.39
# Merging child region PS into region PS
# Loading time for region PS : 0.39
# Merging child region PVp into region PVp
# Loading time for region PVp : 0.39
# Merging child region PVpo into region PVpo
# Loading time for region PVpo : 0.39
# Merging child region SBPV into region SBPV
# Loading time for region SBPV : 0.39
# Merging child region SCH into region SCH
# Loading time for region SCH : 0.39
# Merging child region SFO into region SFO
# Loading time for region SFO : 0.39
# Merging child region VMPO into region VMPO
# Loading time for region VMPO : 0.39
# Merging child region VLPO into region VLPO
# Loading time for region VLPO : 0.39
# Merging child region AHN into region AHN
# Merging child region AHNa into region AHN
# Merging child region AHNc into region AHN
# Merging child region AHNd into region AHN
# Merging child region AHNp into region AHN
# Loading time for region AHN : 1.96
# Merging child region LM into region LM
# Loading time for region LM : 0.40
# Merging child region MM into region MM
# Merging child region Mmme into region MM
# Merging child region Mml into region MM
# Merging child region Mmm into region MM
# Merging child region Mmp into region MM
# Merging child region Mmd into region MM
# Loading time for region MM : 2.36
# Merging child region SUM into region SUM
# Merging child region SUMl into region SUM
# Merging child region SUMm into region SUM
# Loading time for region SUM : 1.18
# Merging child region TMd into region TMd
# Loading time for region TMd : 0.39
# Merging child region TMv into region TMv
# Loading time for region TMv : 0.39
# Merging child region MPN into region MPN
# Merging child region MPNc into region MPN
# Merging child region MPNl into region MPN
# Merging child region MPNm into region MPN
# Loading time for region MPN : 1.56
# Merging child region PMd into region PMd
# Loading time for region PMd : 0.40
# Merging child region PMv into region PMv
# Loading time for region PMv : 0.40
# Merging child region PVHd into region PVHd
# Merging child region PVHdp into region PVHd
# Merging child region PVHf into region PVHd
# Merging child region PVHlp into region PVHd
# Merging child region PVHmpv into region PVHd
# Loading time for region PVHd : 1.98
# Merging child region VMH into region VMH
# Merging child region VMHa into region VMH
# Merging child region VMHc into region VMH
# Merging child region VMHdm into region VMH
# Merging child region VMHvl into region VMH
# Loading time for region VMH : 1.97
# Merging child region PH into region PH
# Loading time for region PH : 0.40
# Merging child region LHA into region LHA
# Loading time for region LHA : 0.42
# Merging child region LPO into region LPO
# Loading time for region LPO : 0.41
# Merging child region PST into region PST
# Loading time for region PST : 0.40
# Merging child region PSTN into region PSTN
# Loading time for region PSTN : 0.40
# Merging child region PeF into region PeF
# Loading time for region PeF : 0.40
# Merging child region RCH into region RCH
# Loading time for region RCH : 0.39
# Merging child region STN into region STN
# Loading time for region STN : 0.40
# Merging child region TU into region TU
# Loading time for region TU : 0.40
# Merging child region ZI into region ZI
# Merging child region A13 into region ZI
# Merging child region FF into region ZI
# Loading time for region ZI : 1.21
# Merging child region ME into region ME
# Loading time for region ME : 0.39
# Merging child region SCs into region SCs
# Merging child region SCop into region SCs
# Merging child region SCsg into region SCs
# Merging child region SCzo into region SCs
# Loading time for region SCs : 1.60
# Merging child region IC into region IC
# Merging child region ICc into region IC
# Merging child region ICd into region IC
# Merging child region ICe into region IC
# Loading time for region IC : 1.60
# Merging child region NB into region NB
# Loading time for region NB : 0.39
# Merging child region SAG into region SAG
# Loading time for region SAG : 0.39
# Merging child region PBG into region PBG
# Loading time for region PBG : 0.39
# Merging child region MEV into region MEV
# Loading time for region MEV : 0.39
# Merging child region SCO into region SCO
# Loading time for region SCO : 0.40
# Merging child region SNr into region SNr
# Loading time for region SNr : 0.40
# Merging child region VTA into region VTA
# Loading time for region VTA : 0.41
# Merging child region PN into region PN
# Loading time for region PN : 0.39
# Merging child region RR into region RR
# Loading time for region RR : 0.39
# Merging child region MRN into region MRN
# Merging child region MRNm into region MRN
# Merging child region MRNmg into region MRN
# Merging child region MRNp into region MRN
# Loading time for region MRN : 1.59
# Merging child region SCm into region SCm
# Merging child region SCdg into region SCm
# Merging child region SCdw into region SCm
# Merging child region SCiw into region SCm
# Merging child region SCig into region SCm
# Merging child region SCig-a into region SCm
# Merging child region SCig-b into region SCm
# Merging child region SCig-c into region SCm
# Loading time for region SCm : 3.14
# Merging child region PAG into region PAG
# Merging child region PRC into region PAG
# Merging child region INC into region PAG
# Merging child region ND into region PAG
# Merging child region Su3 into region PAG
# Loading time for region PAG : 1.99
# Merging child region APN into region APN
# Loading time for region APN : 0.41
# Merging child region MPT into region MPT
# Loading time for region MPT : 0.41
# Merging child region NOT into region NOT
# Loading time for region NOT : 0.41
# Merging child region NPC into region NPC
# Loading time for region NPC : 0.41
# Merging child region OP into region OP
# Loading time for region OP : 0.39
# Merging child region PPT into region PPT
# Loading time for region PPT : 0.40
# Merging child region CUN into region CUN
# Loading time for region CUN : 0.41
# Merging child region RN into region RN
# Loading time for region RN : 0.41
# Merging child region III into region III
# Loading time for region III : 0.39
# Merging child region MA3 into region MA3
# Loading time for region MA3 : 0.40
# Merging child region EW into region EW
# Loading time for region EW : 0.40
# Merging child region IV into region IV
# Loading time for region IV : 0.39
# Merging child region Pa4 into region Pa4
# Loading time for region Pa4 : 0.39
# Merging child region VTN into region VTN
# Loading time for region VTN : 0.39
# Merging child region AT into region AT
# Loading time for region AT : 0.39
# Merging child region LT into region LT
# Loading time for region LT : 0.39
# Merging child region DT into region DT
# Loading time for region DT : 0.39
# Merging child region MT into region MT
# Loading time for region MT : 0.39
# Merging child region SNc into region SNc
# Loading time for region SNc : 0.39
# Merging child region PPN into region PPN
# Loading time for region PPN : 0.39
# Merging child region IF into region IF
# Loading time for region IF : 0.39
# Merging child region IPN into region IPN
# Merging child region IPR into region IPN
# Merging child region IPC into region IPN
# Merging child region IPA into region IPN
# Merging child region IPL into region IPN
# Merging child region IPI into region IPN
# Merging child region IPDM into region IPN
# Merging child region IPDL into region IPN
# Merging child region IPRL into region IPN
# Loading time for region IPN : 3.81
# Merging child region RL into region RL
# Loading time for region RL : 0.39
# Merging child region CLI into region CLI
# Loading time for region CLI : 0.39
# Merging child region DR into region DR
# Loading time for region DR : 0.39
# Merging child region NLL into region NLL
# Merging child region NLLd into region NLL
# Merging child region NLLh into region NLL
# Merging child region NLLv into region NLL
# Loading time for region NLL : 1.55
# Merging child region PSV into region PSV
# Loading time for region PSV : 0.39
# Merging child region PB into region PB
# Merging child region KF into region PB
# Merging child region PBl into region PB
# Merging child region PBlc into region PB
# Merging child region PBld into region PB
# Merging child region PBle into region PB
# Merging child region PBls into region PB
# Merging child region PBlv into region PB
# Merging child region PBm into region PB
# Merging child region PBme into region PB
# Merging child region PBmm into region PB
# Merging child region PBmv into region PB
# Loading time for region PB : 4.64
# Merging child region SOC into region SOC
# Merging child region POR into region SOC
# Merging child region SOCm into region SOC
# Merging child region SOCl into region SOC
# Loading time for region SOC : 1.55
# Merging child region B into region B
# Loading time for region B : 0.39
# Merging child region DTN into region DTN
# Loading time for region DTN : 0.39
# Merging child region PDTg into region PDTg
# Loading time for region PDTg : 0.39
# Merging child region PCG into region PCG
# Loading time for region PCG : 0.39
# Merging child region PG into region PG
# Loading time for region PG : 0.39
# Merging child region PRNc into region PRNc
# Loading time for region PRNc : 0.39
# Merging child region SG into region SG
# Loading time for region SG : 0.39
# Merging child region SUT into region SUT
# Loading time for region SUT : 0.39
# Merging child region TRN into region TRN
# Loading time for region TRN : 0.39
# Merging child region V into region V
# Loading time for region V : 0.39
# Merging child region P5 into region P5
# Loading time for region P5 : 0.39
# Merging child region Acs5 into region Acs5
# Loading time for region Acs5 : 0.40
# Merging child region PC5 into region PC5
# Loading time for region PC5 : 0.40
# Merging child region I5 into region I5
# Loading time for region I5 : 0.41
# Merging child region CS into region CS
# Merging child region CSl into region CS
# Merging child region CSm into region CS
# Loading time for region CS : 1.20
# Merging child region LC into region LC
# Loading time for region LC : 0.38
# Merging child region LDT into region LDT
# Loading time for region LDT : 0.38
# Merging child region NI into region NI
# Loading time for region NI : 0.38
# Merging child region PRNr into region PRNr
# Loading time for region PRNr : 0.40
# Merging child region RPO into region RPO
# Loading time for region RPO : 0.39
# Merging child region SLC into region SLC
# Loading time for region SLC : 0.39
# Merging child region SLD into region SLD
# Loading time for region SLD : 0.40
# Merging child region AP into region AP
# Loading time for region AP : 0.39
# Merging child region DCO into region DCO
# Loading time for region DCO : 0.40
# Merging child region VCO into region VCO
# Loading time for region VCO : 0.40
# Merging child region CU into region CU
# Loading time for region CU : 0.40
# Merging child region GR into region GR
# Loading time for region GR : 0.40
# Merging child region ECU into region ECU
# Loading time for region ECU : 0.40
# Merging child region NTB into region NTB
# Loading time for region NTB : 0.40
# Merging child region NTS into region NTS
# Merging child region NTSce into region NTS
# Merging child region NTSco into region NTS
# Merging child region NTSge into region NTS
# Merging child region NTSl into region NTS
# Merging child region NTSm into region NTS
# Loading time for region NTS : 2.43
# Merging child region SPVC into region SPVC
# Loading time for region SPVC : 0.40
# Merging child region SPVI into region SPVI
# Loading time for region SPVI : 0.40
# Merging child region SPVO into region SPVO
# Merging child region SPVOcdm into region SPVO
# Merging child region SPVOmdmd into region SPVO
# Merging child region SPVOmdmv into region SPVO
# Merging child region SPVOrdm into region SPVO
# Merging child region SPVOvl into region SPVO
# Loading time for region SPVO : 2.34
# Merging child region Pa5 into region Pa5
# Loading time for region Pa5 : 0.39
# Merging child region VI into region VI
# Loading time for region VI : 0.39
# Merging child region VII into region VII
# Loading time for region VII : 0.39
# Merging child region ACVII into region ACVII
# Loading time for region ACVII : 0.40
# Merging child region AMB into region AMB
# Merging child region AMBd into region AMB
# Merging child region AMBv into region AMB
# Loading time for region AMB : 1.19
# Merging child region DMX into region DMX
# Loading time for region DMX : 0.39
# Merging child region GRN into region GRN
# Loading time for region GRN : 0.40
# Merging child region ICB into region ICB
# Loading time for region ICB : 0.39
# Merging child region IO into region IO
# Loading time for region IO : 0.39
# Merging child region IRN into region IRN
# Loading time for region IRN : 0.40
# Merging child region ISN into region ISN
# Loading time for region ISN : 0.40
# Merging child region LIN into region LIN
# Loading time for region LIN : 0.39
# Merging child region LRN into region LRN
# Merging child region LRNm into region LRN
# Merging child region LRNp into region LRN
# Loading time for region LRN : 1.17
# Merging child region MARN into region MARN
# Loading time for region MARN : 0.39
# Merging child region MDRN into region MDRN
# Merging child region MDRNd into region MDRN
# Merging child region MDRNv into region MDRN
# Loading time for region MDRN : 1.18
# Merging child region MDRNd into region MDRNd
# Loading time for region MDRNd : 0.40
# Merging child region MDRNv into region MDRNv
# Loading time for region MDRNv : 0.40
# Merging child region PARN into region PARN
# Loading time for region PARN : 0.40
# Merging child region PAS into region PAS
# Loading time for region PAS : 0.39
# Merging child region PGRNd into region PGRNd
# Loading time for region PGRNd : 0.40
# Merging child region PGRNl into region PGRNl
# Loading time for region PGRNl : 0.39
# Merging child region NR into region NR
# Loading time for region NR : 0.39
# Merging child region PRP into region PRP
# Loading time for region PRP : 0.39
# Merging child region PPY into region PPY
# Merging child region PPYd into region PPY
# Merging child region PPYs into region PPY
# Loading time for region PPY : 1.16
# Merging child region LAV into region LAV
# Loading time for region LAV : 0.39
# Merging child region MV into region MV
# Loading time for region MV : 0.40
# Merging child region SPIV into region SPIV
# Loading time for region SPIV : 0.39
# Merging child region SUV into region SUV
# Loading time for region SUV : 0.39
# Merging child region x into region x
# Loading time for region x : 0.39
# Merging child region XII into region XII
# Loading time for region XII : 0.39
# Merging child region y into region y
# Loading time for region y : 0.39
# Merging child region RM into region RM
# Loading time for region RM : 0.39
# Merging child region RPA into region RPA
# Loading time for region RPA : 0.39
# Merging child region RO into region RO
# Loading time for region RO : 0.39
# Merging child region LING into region LING
# Merging child region LINGmo into region LING
# Merging child region LINGpu into region LING
# Merging child region LINGgr into region LING
# Loading time for region LING : 1.55
# Merging child region CENT into region CENT
# Merging child region CENT2 into region CENT
# Merging child region CENT2mo into region CENT
# Merging child region CENT2pu into region CENT
# Merging child region CENT2gr into region CENT
# Merging child region CENT3 into region CENT
# Merging child region CENT3mo into region CENT
# Merging child region CENT3pu into region CENT
# Merging child region CENT3gr into region CENT
# Loading time for region CENT : 3.53
# Merging child region CUL into region CUL
# Merging child region CUL4 into region CUL
# Merging child region CUL4mo into region CUL
# Merging child region CUL4pu into region CUL
# Merging child region CUL4gr into region CUL
# Merging child region CUL5 into region CUL
# Merging child region CUL5mo into region CUL
# Merging child region CUL5pu into region CUL
# Merging child region CUL5gr into region CUL
# Merging child region CUL4, 5 into region CUL
# Merging child region CUL4, 5mo into region CUL
# Merging child region CUL4, 5pu into region CUL
# Merging child region CUL4, 5gr into region CUL
# Loading time for region CUL : 5.18
# Merging child region DEC into region DEC
# Merging child region DECmo into region DEC
# Merging child region DECpu into region DEC
# Merging child region DECgr into region DEC
# Loading time for region DEC : 1.57
# Merging child region FOTU into region FOTU
# Merging child region FOTUmo into region FOTU
# Merging child region FOTUpu into region FOTU
# Merging child region FOTUgr into region FOTU
# Loading time for region FOTU : 1.59
# Merging child region PYR into region PYR
# Merging child region PYRmo into region PYR
# Merging child region PYRpu into region PYR
# Merging child region PYRgr into region PYR
# Loading time for region PYR : 1.57
# Merging child region UVU into region UVU
# Merging child region UVUmo into region UVU
# Merging child region UVUpu into region UVU
# Merging child region UVUgr into region UVU
# Loading time for region UVU : 1.58
# Merging child region NOD into region NOD
# Merging child region NODmo into region NOD
# Merging child region NODpu into region NOD
# Merging child region NODgr into region NOD
# Loading time for region NOD : 1.58
# Merging child region SIM into region SIM
# Merging child region SIMmo into region SIM
# Merging child region SIMpu into region SIM
# Merging child region SIMgr into region SIM
# Loading time for region SIM : 1.60
# Merging child region AN into region AN
# Merging child region ANcr1 into region AN
# Merging child region ANcr1mo into region AN
# Merging child region ANcr1pu into region AN
# Merging child region ANcr1gr into region AN
# Merging child region ANcr2 into region AN
# Merging child region ANcr2mo into region AN
# Merging child region ANcr2pu into region AN
# Merging child region ANcr2gr into region AN
# Loading time for region AN : 3.56
# Merging child region PRM into region PRM
# Merging child region PRMmo into region PRM
# Merging child region PRMpu into region PRM
# Merging child region PRMgr into region PRM
# Loading time for region PRM : 1.58
# Merging child region COPY into region COPY
# Merging child region COPYmo into region COPY
# Merging child region COPYpu into region COPY
# Merging child region COPYgr into region COPY
# Loading time for region COPY : 1.56
# Merging child region PFL into region PFL
# Merging child region PFLmo into region PFL
# Merging child region PFLpu into region PFL
# Merging child region PFLgr into region PFL
# Loading time for region PFL : 1.59
# Merging child region FL into region FL
# Merging child region FLmo into region FL
# Merging child region FLpu into region FL
# Merging child region FLgr into region FL
# Loading time for region FL : 1.58
# Merging child region FN into region FN
# Loading time for region FN : 0.40
# Merging child region IP into region IP
# Loading time for region IP : 0.40
# Merging child region DN into region DN
# Loading time for region DN : 0.39
# Merging child region VeCB into region VeCB
# Loading time for region VeCB : 0.39
# Merging child region fiber tracts into region fiber tracts
# Merging child region cm into region fiber tracts
# Merging child region tn into region fiber tracts
# Merging child region von into region fiber tracts
# Merging child region In into region fiber tracts
# Merging child region onl into region fiber tracts
# Merging child region lotg into region fiber tracts
# Merging child region lot into region fiber tracts
# Merging child region lotd into region fiber tracts
# Merging child region aolt into region fiber tracts
# Merging child region aco into region fiber tracts
# Merging child region IIn into region fiber tracts
# Merging child region aot into region fiber tracts
# Merging child region bsc into region fiber tracts
# Merging child region csc into region fiber tracts
# Merging child region och into region fiber tracts
# Merging child region opt into region fiber tracts
# Merging child region ttp into region fiber tracts
# Merging child region IIIn into region fiber tracts
# Merging child region mlf into region fiber tracts
# Merging child region pc into region fiber tracts
# Merging child region IVn into region fiber tracts
# Merging child region IVd into region fiber tracts
# Merging child region VIn into region fiber tracts
# Merging child region Vn into region fiber tracts
# Merging child region moV into region fiber tracts
# Merging child region sV into region fiber tracts
# Merging child region mtV into region fiber tracts
# Merging child region sptV into region fiber tracts
# Merging child region VIIn into region fiber tracts
# Merging child region iVIIn into region fiber tracts
# Merging child region gVIIn into region fiber tracts
# Merging child region VIIIn into region fiber tracts
# Merging child region cvb into region fiber tracts
# Merging child region vVIIIn into region fiber tracts
# Merging child region cVIIIn into region fiber tracts
# Merging child region tb into region fiber tracts
# Merging child region ias into region fiber tracts
# Merging child region das into region fiber tracts
# Merging child region ll into region fiber tracts
# Merging child region cic into region fiber tracts
# Merging child region bic into region fiber tracts
# Merging child region IXn into region fiber tracts
# Merging child region Xn into region fiber tracts
# Merging child region ts into region fiber tracts
# Merging child region XIn into region fiber tracts
# Merging child region XIIn into region fiber tracts
# Merging child region vrt into region fiber tracts
# Merging child region drt into region fiber tracts
# Merging child region cett into region fiber tracts
# Merging child region dl into region fiber tracts
# Merging child region dcm into region fiber tracts
# Merging child region vc into region fiber tracts
# Merging child region fpr into region fiber tracts
# Merging child region dc into region fiber tracts
# Merging child region cuf into region fiber tracts
# Merging child region grf into region fiber tracts
# Merging child region iaf into region fiber tracts
# Merging child region ml into region fiber tracts
# Merging child region sst into region fiber tracts
# Merging child region sttl into region fiber tracts
# Merging child region sttv into region fiber tracts
# Merging child region scrt into region fiber tracts
# Merging child region sop into region fiber tracts
# Merging child region srp into region fiber tracts
# Merging child region svp into region fiber tracts
# Merging child region stp into region fiber tracts
# Merging child region shp into region fiber tracts
# Merging child region step into region fiber tracts
# Merging child region hht into region fiber tracts
# Merging child region cbf into region fiber tracts
# Merging child region cbc into region fiber tracts
# Merging child region cbp into region fiber tracts
# Merging child region scp into region fiber tracts
# Merging child region dscp into region fiber tracts
# Merging child region sct into region fiber tracts
# Merging child region uf into region fiber tracts
# Merging child region sctv into region fiber tracts
# Merging child region mcp into region fiber tracts
# Merging child region icp into region fiber tracts
# Merging child region sctd into region fiber tracts
# Merging child region cct into region fiber tracts
# Merging child region jrb into region fiber tracts
# Merging child region bct into region fiber tracts
# Merging child region oct into region fiber tracts
# Merging child region rct into region fiber tracts
# Merging child region tct into region fiber tracts
# Merging child region arb into region fiber tracts
# Merging child region scwm into region fiber tracts
# Merging child region lfbs into region fiber tracts
# Merging child region cc into region fiber tracts
# Merging child region fa into region fiber tracts
# Merging child region ec into region fiber tracts
# Merging child region ee into region fiber tracts
# Merging child region ccg into region fiber tracts
# Merging child region fp into region fiber tracts
# Merging child region ccr into region fiber tracts
# Merging child region ccb into region fiber tracts
# Merging child region ccs into region fiber tracts
# Merging child region cst into region fiber tracts
# Merging child region int into region fiber tracts
# Merging child region cpd into region fiber tracts
# Merging child region cte into region fiber tracts
# Merging child region crt into region fiber tracts
# Merging child region cpt into region fiber tracts
# Merging child region cbt into region fiber tracts
# Merging child region py into region fiber tracts
# Merging child region pyd into region fiber tracts
# Merging child region cstc into region fiber tracts
# Merging child region cstu into region fiber tracts
# Merging child region lfbst into region fiber tracts
# Merging child region em into region fiber tracts
# Merging child region im into region fiber tracts
# Merging child region mtc into region fiber tracts
# Merging child region tp into region fiber tracts
# Merging child region or into region fiber tracts
# Merging child region ar into region fiber tracts
# Merging child region eps into region fiber tracts
# Merging child region epsc into region fiber tracts
# Merging child region pap into region fiber tracts
# Merging child region nst into region fiber tracts
# Merging child region ntt into region fiber tracts
# Merging child region ptf into region fiber tracts
# Merging child region snp into region fiber tracts
# Merging child region stf into region fiber tracts
# Merging child region tsp into region fiber tracts
# Merging child region tspd into region fiber tracts
# Merging child region dtd into region fiber tracts
# Merging child region tspc into region fiber tracts
# Merging child region rust into region fiber tracts
# Merging child region vtd into region fiber tracts
# Merging child region rrt into region fiber tracts
# Merging child region ctb into region fiber tracts
# Merging child region rst into region fiber tracts
# Merging child region rstl into region fiber tracts
# Merging child region rstm into region fiber tracts
# Merging child region vsp into region fiber tracts
# Merging child region mfbs into region fiber tracts
# Merging child region mfbc into region fiber tracts
# Merging child region amc into region fiber tracts
# Merging child region apd into region fiber tracts
# Merging child region act into region fiber tracts
# Merging child region cing into region fiber tracts
# Merging child region fxs into region fiber tracts
# Merging child region alv into region fiber tracts
# Merging child region df into region fiber tracts
# Merging child region fi into region fiber tracts
# Merging child region fxprg into region fiber tracts
# Merging child region db into region fiber tracts
# Merging child region fxpo into region fiber tracts
# Merging child region mct into region fiber tracts
# Merging child region fx into region fiber tracts
# Merging child region hc into region fiber tracts
# Merging child region dhc into region fiber tracts
# Merging child region vhc into region fiber tracts
# Merging child region per into region fiber tracts
# Merging child region ab into region fiber tracts
# Merging child region lab into region fiber tracts
# Merging child region st into region fiber tracts
# Merging child region stc into region fiber tracts
# Merging child region mfsbshy into region fiber tracts
# Merging child region mfb into region fiber tracts
# Merging child region vlt into region fiber tracts
# Merging child region poc into region fiber tracts
# Merging child region sup into region fiber tracts
# Merging child region supa into region fiber tracts
# Merging child region supd into region fiber tracts
# Merging child region supv into region fiber tracts
# Merging child region pmx into region fiber tracts
# Merging child region smd into region fiber tracts
# Merging child region php into region fiber tracts
# Merging child region phpd into region fiber tracts
# Merging child region phpl into region fiber tracts
# Merging child region phpm into region fiber tracts
# Merging child region phpv into region fiber tracts
# Merging child region pvbh into region fiber tracts
# Merging child region mfbsma into region fiber tracts
# Merging child region pm into region fiber tracts
# Merging child region mtt into region fiber tracts
# Merging child region mtg into region fiber tracts
# Merging child region mp into region fiber tracts
# Merging child region mfbst into region fiber tracts
# Merging child region pvbt into region fiber tracts
# Merging child region mfbse into region fiber tracts
# Merging child region sm into region fiber tracts
# Merging child region fr into region fiber tracts
# Merging child region hbc into region fiber tracts
# Merging child region PIS into region fiber tracts
# Merging child region mfbsm into region fiber tracts
# Merging child region dlf into region fiber tracts
# Merging child region dtt into region fiber tracts
# Loading time for region fiber tracts : 75.94

# %%
region_all, count = np.unique(mergeccf, return_counts=True)
len(region_all)
# Out:
# 316

# %%
Result_temp= mergeccf .copy()
Result_temp[(mergeRlist>0)] = mergeRlist[(mergeRlist>0)] 
Result_temp = np.swapaxes(Result_temp,0,2)
Result_temp.shape
# Out:
# (456, 320, 528)

# %%
FinalResult = np.zeros((456, 320, 568))
FinalResult [:,:,:528] = Result_temp

# %%
region_all, count = np.unique(FinalResult, return_counts=True)
len(region_all)
# Out:
# 168

# %%
import SimpleITK as sitk
path = '/home/penglab/Desktop'
folder = os.path.exists(path)
if not folder:         
    os.makedirs(path)  

FinalResult= FinalResult.astype(np.int16)
filename = str(path)+ '/'
filename = filename + str('Nov11')
filename = filename +'.nrrd'
itkimage = sitk.GetImageFromArray(FinalResult, isVector=False)
sitk.WriteImage(itkimage, filename, True)

# %% [markdown]
# **seu_ns: SEU-Allen's data**
#
# **all_ns: SEU + Janelia's data**

# %% [markdown]
# Input .swc data file, total **1602**.

# %%
import pickle
pickle_in = open("/home/penglab/FeaCal/all_ns.pickle","rb")
[ns] = pickle.load(pickle_in)

# %%
_ = ns.ReduceDimUMAP(feature_set="projection_features", n_neighbors=100)

# %% [markdown]
# ns = nmt.neuron_set('/home/penglab/FeaCal/allData')
# pickle.dump([ns], open("/home/penglab/FeaCal/all_ns.pickle", "wb"))

# %% [markdown]
# # 2.1) Distribution of soma location
# * Set the *thre* value to determine the threshold for showing the region distribution
# * mouseDF is a dataframe recording the ['Child ID', 'Child num', 'ABBR', 'FatherRe'] of 1327 brain regions
# * Not going to write mouseDF to the pkg, just to show the result

# %% [markdown]
# ## 2.1.1) Based on 7 regions
# * including Isocortex, OLF, HPF, CTXsp, CNU, BS, CB;

# %%
mouseDF = pd.read_excel('/home/penglab/FeaCal/dataSource/mouseDF.xlsx',index=0)
abbrlist = []
for i in mouseDF.loc[:,'idx']:
    if i in nmt.bs.level.index:
        abbr = nmt.bs.level.loc[i,'Abbreviation']
        abbrlist.append(abbr)
    else:
        print(i)
        abbrlist.append('unknown')
mouseDF.loc[:,'ABBR']=abbrlist
del mouseDF[1]
mouseDF.set_index(['idx'],inplace=True)

somaRegDF = ns.features['soma_features'].region.copy()
large_list = [ 'BS', 'CB','CNU', 'CTXsp', 'HPF','Isocortex', 'OLF']
mouseDF['FatherRe'] = mouseDF.loc[:,'ABBR']
        
for B_iter in large_list :
    temp=[]
    if nmt.bs.name_to_id(B_iter) in mouseDF.index:
        for child_iter in mouseDF.loc[nmt.bs.name_to_id(B_iter),'Child ID'].split():
            if int(child_iter) in mouseDF.index:
                mouseDF.loc[int(child_iter),'FatherRe'] = B_iter
            else:
                print(child_iter)
            #temp.append(nmt.bs.level.loc[int(child_iter),'Abbrevation'])
somaRegDF['main7Region'] = somaRegDF['Region']     
for iterR in somaRegDF.index:
    if somaRegDF.loc[iterR,'Region'] in mouseDF['ABBR'].tolist():
        somaRegDF.loc[iterR,'main7Region'] = mouseDF[mouseDF['ABBR']==somaRegDF.loc[iterR,'Region']].iloc[0,-1]

# %%
ct = somaRegDF["main7Region"].value_counts().sort_values(ascending=False)
thre = 0
sns.set(rc={'figure.figsize':(8,5)})
_ = sns.countplot(y="main7Region", 
                  data=somaRegDF.loc[somaRegDF.main7Region.isin(ct.index[ct>thre])],
                  hue = "main7Region", palette="Set3"
                 )

# %% [markdown]
# ## 2.1.2) Projecting to three directions: "Horizontal","Coronal","Sagittal"
#
# **2.1.2.1) By setting color="majorSOMA" in cell_in_map, the soma point will be shown with 7 major regions**
# * Here set the 'Cluster' column in ns.metadata to be the region name.
#
# **2.1.2.2) By setting color="soma" in cell_in_map, the soma point will be shown with 256 colors**
# * No need to set the 'Cluster' column in ns.metadata to be the region name.

# %% [markdown]
# <blockquote>Example: Plot three views in a single plot with 256 color</blockquote>
#
# ```Python
#     from neuro_morpho_toolbox.plot import cell_in_map
#     fig, ax = plt.subplots(3,1, figsize=(7.5, 10))
#     cur_list = ns.metadata.index.tolist()
#     cell_in_map(ns.neurons, cur_list, ns.metadata, ccf_annotation=nmt.annotation,
#                 view="Horizontal", color="soma",alpha=1,ax=ax[0])
#     cell_in_map(ns.neurons, cur_list, ns.metadata,ccf_annotation=nmt.annotation,
#                 view="Coronal", color="soma", alpha=1,ax=ax[1])
#     cell_in_map(ns.neurons,cur_list, ns.metadata, ccf_annotation=nmt.annotation,
#                 view="Sagittal", color="soma", alpha=1, ax=ax[2])
#     #fig.savefig('../Figure/Cell_in_map.pdf')
# ```

# %% [markdown]
# **2.1.2.1)  Plot singel view('Horizontal') with only 7 major regions**

# %%
from neuro_morpho_toolbox.plot import cell_in_map
fig, ax =  plt.subplots(1,1)
cur_list = ns.metadata.index.tolist()
somaRegDF['Cluster']= somaRegDF.loc[:,'main7Region']
somaRegDF
cell_in_map(ns.neurons, cur_list, somaRegDF,ccf_annotation=nmt.annotation,view="Horizontal",color="majorsoma",ax=ax
           )
#fig.savefig('/home/penglab/FeaCal/horizonsaved')
# Out:
# Illustrating soma locations inside a brain from horizontal view:

# %% [markdown]
# **2.1.2.2) Plot singel view('Horizontal') with all regions**

# %%
from neuro_morpho_toolbox.plot import cell_in_map
cur_list = ns.metadata.index.tolist()
somaRegDF
cell_in_map(ns.neurons, cur_list, ns.metadata,ccf_annotation=nmt.annotation,view="Horizontal", color="soma")
#fig.savefig('/home/penglab/FeaCal/horizonsaved')
# Out:
# Illustrating soma locations inside a brain from horizontal view:

# %% [markdown]
# ## 2.1.3) Use wordcloud to illustrate the information
# * Not going to write into the pkg just to show the result

# %%
import jieba               
from wordcloud import WordCloud   
from PIL import Image
img = np.array(Image.open("/home/penglab/Desktop/mask.png"))
region_all, count = np.unique(somaRegDF['Region'], return_counts=True)
somaDIC = {}
for i in range(len(region_all)):
    #if region_all[i] == 'fiber tracts':
        #continue
    somaDIC[region_all[i]] = count[i]

wc = WordCloud(background_color='white',width=240,height=160,max_font_size=75,min_font_size=5,
               colormap="viridis", mask = img)
wc.generate_from_frequencies(somaDIC)
#save the file
wc.to_file('/home/penglab/Desktop/WC.png') 
# Show the plot
plt.figure(figsize=(10,20)) 
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## 1.1) Analyze soma location to obtain confident list

# %% [markdown]
# **Read the downsample-25 array with selected CCF region**

# %% [markdown]
# <blockquote>Example
#
# ```Python
# nmt.ccfArray
# ```
# </blockquote>

# %% [markdown]
# **Read the 6-nearest neighbor Contour Matrix with CCF index on**
#
# * Originally, selected CCF has *316* regions, after using all the selected index to replace the child region, there are *337* regions.
# * Therefore, there are 23 regions that show up in the nrrd array but have not been mentioned in the above selected CCF or its child region

# %% [markdown]
# <blockquote>Example
#
# ```Python
# nmt.Contour01
# ```
# </blockquote>

# %% [markdown]
# ***Use nmt.disCal to obtain a DataFrame with columns ['x', 'y', 'z', 'SqEuclidean', 'min_Euclidean']***

# %% [markdown]
# <blockquote>Example
# </blockquote>
#
# ```Python
#     somaDis = nmt.disCal(ns.features['soma_features'].raw_data,
#                          CCF_6_01,ccfArray, 10, flipF = True)
# ```

# %%
pickle_in = open("/home/penglab/NMTcode/somaDis.pickle","rb")
example_ = pickle.load(pickle_in)
somaDis = example_[0]

# %% [markdown]
# SelectedDF is obtained by throwing the unknown region and fiber tracts soma away

# %%
selectedDF = somaDis[somaDis['SqEuclidean'] != 'unknown'].copy()
selectedDF = selectedDF[selectedDF['Region'] != 'fiber tracts'].copy()
confi_list = selectedDF.index.tolist()
print('Number of confident neurons are '+ str(len(confi_list)))
se_list = selectedDF.index.tolist()
# Out:
# Number of confident neurons are 1006

# %% [markdown]
# ## Calculate ARI according to a given list

# %% [markdown]
# ### Generate the dataframe using pickCLUSTERpara(method)

# %% [markdown]
# <blockquote>Example</blockquote>
#
# ```Python
#     hier_resultDF = ns.pickCLUSTERpara('hierarchy',se_list)
#     kmeans_resultDF = ns.pickCLUSTERpara('kmeans',se_list)
#     dbscan_resultDF = ns.pickCLUSTERpara('dbscan',se_list)
#     hdbscan_resultDF = ns.pickCLUSTERpara('hdbscan',se_list)
#     snn_resultDF = ns.pickCLUSTERpara('snn',se_list)
# ```
# or if want to calculate ARI for all neurons, just use
# ```Python
#     hier_resultDF = ns.pickCLUSTERpara('hierarchy')
#     kmeans_resultDF = ns.pickCLUSTERpara('kmeans')
#     dbscan_resultDF = ns.pickCLUSTERpara('dbscan')
#     hdbscan_resultDF = ns.pickCLUSTERpara('hdbscan')
#     snn_resultDF = ns.pickCLUSTERpara('snn')
# ```

# %% [markdown]
# ### Print out the most proper parameter by maximizing ARI

# %% [markdown]
# <blockquote>Example</blockquote>
#
# ```Python
#     hierbest = findBESTpara(hier_resultDF,[15,45],16)
#     kmeansbest = findBESTpara(kmeans_resultDF,[15,45],16)
#     dbscanbest = findBESTpara(dbscan_resultDF,[15,45],16)
#     hdbscanbest = findBESTpara(hdbscan_resultDF,[15,45],16)
#     snnbest = findBESTpara(snn_resultDF,[15,45],16)
# ```

# %% [markdown]
# ## Using co-clustering towards the selected parameters

# %%
from scipy.spatial import distance
from scipy.cluster import hierarchy
import numpy as np

from scipy.cluster.hierarchy import linkage, dendrogram, fcluster,inconsistent
#print the cocluster result
#output the linkage matrix
def bestCOCLUSTER(df,axis_color,input_ns = None):
    linkmethod = ['single', 'complete','average','weighted','centroid','median','ward']
    paraDF = pd.DataFrame(columns =['method','CCC'],index = linkmethod)
    paraDF.loc[:,'method'] = linkmethod
    
    for iter_m in linkmethod:
        Y = distance.pdist(np.asarray(df))
        Z = hierarchy.linkage(Y, method = iter_m)
        c, coph_dists = hierarchy.cophenet(Z,Y)
        paraDF.loc[iter_m,'cophentic_correlation_dis'] = c
    paraDF.sort_values(by='cophentic_correlation_dis', ascending = False, inplace = True)
    # choose the linkage method which maximizes the cophentic correlation distance
    if type(axis_color) == dict:
        colorDF = pd.DataFrame(index = ns.metadata.index,data = ns.metadata['CellType'], columns = ['CellType'])
        for iter_idx in colorDF.index:
            colorDF.loc[iter_idx,'Color'] = axis_color[colorDF.loc[iter_idx,'CellType']]
        axis_color = colorDF['Color']
    row_linkage = hierarchy.linkage(distance.pdist(np.asarray(df)), method = paraDF.iloc[0,0])
    col_linkage = hierarchy.linkage(distance.pdist(np.asarray(df).T), method = paraDF.iloc[0,0])
    #print(paraDF.iloc[0,0])
    sns.clustermap(df, row_linkage = row_linkage, col_linkage = col_linkage, row_colors=axis_color,
                   col_colors = axis_color)#, figsize=(13, 13))#, cmap=sns.diverging_palette(h_neg=150, h_pos=275, s=80, l=55, as_cmap=True))    
    return hierarchy.linkage(distance.pdist(np.asarray(df)))



def coclusterResult(Z_sample):
    t = input('Please input the number of cluster: ')
    return fcluster(Z_sample,t,criterion='maxclust')

# %% [markdown]
# ## Feature 1: projection patterns

# %%
_ = ns.ReduceDimUMAP(feature_set="projection_features", n_neighbors=100)

# %%
AP_hierDF = pd.read_excel('/home/penglab/NMTcode/AP_hier_co_cluster.xlsx', index_col=0)
AP_kmeansDF = pd.read_excel('/home/penglab/NMTcode/AP_kmeans_co_cluster.xlsx', index_col=0)
AP_dbscanDF = pd.read_excel('/home/penglab/NMTcode/AP_dbscan_co_cluster.xlsx', index_col=0)
AP_hdbscanDF = pd.read_excel('/home/penglab/NMTcode/AP_hdbscan_co_cluster.xlsx', index_col=0)
AP_snnDF = pd.read_excel('/home/penglab/NMTcode/AP_snn_co_cluster.xlsx', index_col=0)

# %%
bestCOCLUSTER(AP_hierDF,nmt.get_group_colors(ns.metadata, group_by="CellType", palette="paired", return_str = True,return_hex = True),ns)
# Out:
# array([[7.54000000e+02, 1.30500000e+03, 2.95648440e+02, 2.00000000e+00],
#        [1.30300000e+03, 1.58700000e+03, 2.97714628e+02, 3.00000000e+00],
#        [8.39000000e+02, 1.45100000e+03, 2.97857348e+02, 2.00000000e+00],
#        ...,
#        [2.68300000e+03, 3.16900000e+03, 3.80885307e+04, 1.39600000e+03],
#        [3.11100000e+03, 3.17000000e+03, 4.03669418e+04, 1.49600000e+03],
#        [2.64800000e+03, 3.17100000e+03, 4.41709085e+04, 1.58700000e+03]])

# %%
bestCOCLUSTER(AP_kmeansDF,nmt.get_group_colors(ns.metadata, group_by="CellType", palette="paired", return_str = True,return_hex = True),ns)
# Out:
# array([[7.45000000e+02, 1.08000000e+03, 3.05622316e+02, 2.00000000e+00],
#        [7.41000000e+02, 7.93000000e+02, 3.17181336e+02, 2.00000000e+00],
#        [6.20000000e+02, 1.14300000e+03, 3.18463499e+02, 2.00000000e+00],
#        ...,
#        [3.03800000e+03, 3.16900000e+03, 3.63497960e+04, 1.39600000e+03],
#        [3.13500000e+03, 3.17000000e+03, 3.73830286e+04, 1.49600000e+03],
#        [2.97300000e+03, 3.17100000e+03, 3.82810399e+04, 1.58700000e+03]])

# %%
bestCOCLUSTER(AP_dbscanDF,nmt.get_group_colors(ns.metadata, group_by="CellType", palette="paired", return_str = True,return_hex = True),ns)
# Out:
# array([[1.22600000e+03, 1.43200000e+03, 2.81572371e+02, 2.00000000e+00],
#        [1.34300000e+03, 1.53000000e+03, 2.85457527e+02, 2.00000000e+00],
#        [8.20000000e+01, 3.21000000e+02, 2.89634252e+02, 2.00000000e+00],
#        ...,
#        [3.10100000e+03, 3.16900000e+03, 3.74483665e+04, 1.27500000e+03],
#        [3.11700000e+03, 3.17000000e+03, 4.07588419e+04, 1.39900000e+03],
#        [2.86000000e+03, 3.17100000e+03, 4.98544562e+04, 1.58700000e+03]])

# %%
bestCOCLUSTER(AP_hdbscanDF,nmt.get_group_colors(ns.metadata, group_by="CellType", palette="paired", return_str = True,return_hex = True),ns)
# Out:
# array([[1.77000000e+02, 4.06000000e+02, 2.89530655e+02, 2.00000000e+00],
#        [1.23900000e+03, 1.42100000e+03, 2.92058213e+02, 2.00000000e+00],
#        [4.05000000e+02, 1.58700000e+03, 2.92924905e+02, 3.00000000e+00],
#        ...,
#        [3.13400000e+03, 3.16900000e+03, 3.12387811e+04, 1.42900000e+03],
#        [2.94300000e+03, 3.17000000e+03, 3.75056081e+04, 1.49500000e+03],
#        [2.56600000e+03, 3.17100000e+03, 4.46896028e+04, 1.58700000e+03]])

# %%
bestCOCLUSTER(AP_snnDF,nmt.get_group_colors(ns.metadata, group_by="CellType", palette="paired", return_str = True,return_hex = True),ns)
# Out:
# array([[9.76000000e+02, 1.31400000e+03, 2.90449651e+02, 2.00000000e+00],
#        [8.52000000e+02, 1.58700000e+03, 2.99506260e+02, 3.00000000e+00],
#        [1.05100000e+03, 1.58800000e+03, 3.02603701e+02, 4.00000000e+00],
#        ...,
#        [3.13300000e+03, 3.16900000e+03, 2.98541540e+04, 1.43000000e+03],
#        [2.51000000e+03, 3.17000000e+03, 3.86970844e+04, 1.49600000e+03],
#        [3.10900000e+03, 3.17100000e+03, 3.96882346e+04, 1.58700000e+03]])

# %%
plt.figure()
hierarchy.set_link_color_palette(['g', 'r', 'c', 'm', 'y', 'k'])
Z = hierarchy.linkage(np.asarray(AP_hierDF, 'single'))
dn = hierarchy.dendrogram(Z, labels = AP_hierDF.index, p=10, truncate_mode='lastp')

# %%
dn['dcoord']
# Out:
# [[0.0, 23475.7083173224, 23475.7083173224, 0.0],
#  [0.0, 25191.982256265583, 25191.982256265583, 23475.7083173224],
#  [0.0, 27922.25216561157, 27922.25216561157, 25191.982256265583],
#  [0.0, 28438.176699640924, 28438.176699640924, 27922.25216561157],
#  [0.0, 31040.081926438274, 31040.081926438274, 28438.176699640924],
#  [0.0, 35187.50852220145, 35187.50852220145, 31040.081926438274],
#  [0.0, 38088.53066212977, 38088.53066212977, 35187.50852220145],
#  [0.0, 40366.94182124774, 40366.94182124774, 38088.53066212977],
#  [0.0, 44170.908480582555, 44170.908480582555, 40366.94182124774]]

# %% [markdown]
# ## Feature 2: Soma Location

# %%
SL_hierDF = pd.read_excel('/home/penglab/NMTcode/SL_hier_co_cluster.xlsx', index_col=0)
SL_kmeansDF = pd.read_excel('/home/penglab/NMTcode/SL_kmeans_co_cluster.xlsx', index_col=0)
SL_dbscanDF = pd.read_excel('/home/penglab/NMTcode/SL_dbscan_co_cluster.xlsx', index_col=0)
SL_hdbscanDF = pd.read_excel('/home/penglab/NMTcode/SL_hdbscan_co_cluster.xlsx', index_col=0)
SL_snnDF = pd.read_excel('/home/penglab/NMTcode/SL_snn_co_cluster.xlsx', index_col=0)

# %%
bestCOCLUSTER(SL_snnDF,nmt.get_group_colors2(ns.metadata, group_by="CellType", palette="paired", return_str = True,return_hex = True),ns)

# %%
import seaborn as sns; sns.set()




colorlist=["#7FC97F","#BEAED4","#FDC086","#FFFF99","#386CB0","#F0027F","#BF5B17","#666666","#1B9E77","#D95F02",
           "#7570B3","#E7298A","#66A61E","#E6AB02","#A6761D","#666666","#A6CEE3","#1F78B4","#B2DF8A","#33A02C",
           "#FB9A99","#E31A1C","#FDBF6F","#FF7F00","#CAB2D6","#6A3D9A","#FFFF99","#B15928","#FBB4AE","#B3CDE3",
           "#CCEBC5","#DECBE4","#FED9A6","#FFFFCC","#E5D8BD","#FDDAEC","#F2F2F2","#B3E2CD","#FDCDAC","#CBD5E8",
           "#F4CAE4","#E6F5C9","#FFF2AE","#F1E2CC","#CCCCCC","#E41A1C","#377EB8","#4DAF4A","#984EA3","#FF7F00",
           "#FFFF33","#A65628","#F781BF","#999999","#66C2A5","#FC8D62","#8DA0CB","#E78AC3","#A6D854","#FFD92F",
           "#E5C494","#B3B3B3","#8DD3C7","#FFFFB3","#BEBADA","#FB8072","#80B1D3","#FDB462","#B3DE69","#FCCDE5",
           "#D9D9D9","#BC80BD","#CCEBC5"]
lut = dict(zip(ns.metadata['CellType'].unique(), colorlist))
row_colors = ns.metadata['CellType'].map(lut)
row_colors[row_colors.isnull()]='white'

# %%
row_colors[0:6]

# %%
DDD=(nmt.get_group_colors(ns.metadata, group_by="CellType", palette="paired", return_str=False, return_colorCode = ))
bestCOCLUSTER(SL_snnDF,DDD,ns)

# %%
bestCOCLUSTER(SL_snnDF,DDD,ns)

# %%
stoppp

# %%
from scipy.cluster import hierarchy
from scipy.spatial import distance
hierarchy.linkage(distance.pdist(np.asarray(SL_snnDF)), method = 'single')

# %%
Ztemp= bestCOCLUSTER(DM_hierDF)

# %%
import pickle
def generateNS(featureDF,ns_input,Z_sample,storePath,outname):
    if featureDF.shape!= (0,0):
        pickle_in = open("/home/penglab/FeaCal/ns.pickle","rb")
        example_ = pickle.load(pickle_in)
        ns_input= example_[0]

        index_origin = ns_input.metadata.index.tolist()
        ns_input.UMAP = nmt.UMAP_wrapper(featureDF, n_neighbors=100, min_dist=0.1, n_components=2, 
                                         metric='euclidean',PCA_first=True,n_PC=100)
        index_after = ns_input.UMAP.index.tolist()
        if len(index_after)>len(index_origin ):
            index_update = [i for i in index_after if i in index_origin ]
        else:
            index_update = [i for i in index_origin if i in index_after ]
        
        ns_input.metadata = ns_input.metadata.loc[index_update,:]
    cur_clusters = coclusterResult(Z_sample)
    ns_input.metadata['Cluster'] = ['C' + str(i) for i in cur_clusters] 
    _ = ns_input.FeatureScatter(["CellType", "Hemisphere","Cluster"], map="UMAP")
    return ns_input

# %%
AP_hierDF  = DM_hierDF

# %%
Ztemp= bestCOCLUSTER(AP_hierDF)
generateNS(pd.DataFrame(),ns,Ztemp,'/home/penglab/FeaCal/','AP_hier_ns')

# %%
_ = ns.FeatureScatter(["CellType", "Hemisphere","Cluster"], map="UMAP")

# %%
DM_kmeans = para_cocluster('Kmeans', par_kmeans2,30, 5000,ns)
DM_kmeansDF = pd.DataFrame(data=DM_kmeans, index=ns.UMAP.index, columns=ns.UMAP.index)
DM_kmeansDF.to_excel('/home/penglab/FeaCal/dataSource/denMor/DM_kmeansDF.xlsx')

# %%
# df = pd.read_excel("../Subjective_celltype/tracking_table_QW_hz_LjL_08082019.xlsx", index_col=[0])
# metadata = ns.features['soma_features'].region
# df = df.loc[metadata.index]
# df.to_excel("../Subjective_celltype/tracking_table_QW_hz_LjL_08082019.284_cells.xlsx")

# %%
df = pd.read_excel("../Subjective_celltype/tracking_table.284_cells.xlsx", index_col=[0])
region_list = pd.read_excel("../Subjective_celltype/tracking_table.284_cells.xlsx", sheet_name=1, header=None)[2].tolist()

metadata = ns.features['soma_features'].region.copy()
metadata['Celltype'] = df.loc[metadata.index, "Confirmed"]
# # metadata['Celltype_note'] = df.loc[metadata.index, "Lijuan Note"]
# # metadata.loc[metadata["Celltype_note"]=="CPU", "Celltype"] = "CPU"
metadata.fillna("Others", inplace=True)
metadata.loc[metadata.Celltype.isin(["TH", "VPM/VPL"]), "Celltype"] = "TH_Uncertain"
metadata.loc[~metadata.Celltype.isin(["Others", "TH_Uncertain"]+region_list), "Celltype"] = "Others"
print(metadata.Celltype.value_counts())
# metadata
pickle.dump([metadata], open("metadata.pickle", "wb"))

# %% [markdown]
# ## Color setting

# %%
bupu = cl.scales['9']['seq']['BuPu']
greens = cl.scales['9']['seq']['Greens']
set2 = cl.scales['7']['qual']['Set2']
spectral = cl.scales['9']['div']['Spectral']
paired = cl.scales['10']['qual']['Paired']
mpl_colors = []
for i in range(9):
    tp = []
    for j in list(matplotlib.colors.to_rgb("C"+str(i))):
        tp.append(str(int(j*255)))
    tp = ", ".join(tp)
    tp = "rgb(" + tp + ")"
    mpl_colors.append(tp)
   
def rgb_to_list(rgb_str):
    tp = rgb_str.replace("rgb(", "").replace("rgba(", "").replace(")", "")
    res = [float(i)/255 for i in tp.split(", ")]
    return res

def get_celltype_colors(metadata):
    u_celltypes = sorted(list(set(metadata.Celltype)))
    color_list = cl.to_rgb(cl.interp(paired, len(u_celltypes)))
    color_list = [rgb_to_list(i) for i in color_list]
    celltype_colors = dict(zip(u_celltypes, color_list))
    if "Others" in u_celltypes:
        celltype_colors["Others"] = rgb_to_list('rgb(128, 128, 128)')
    return celltype_colors

celltype_color_dict = get_celltype_colors(metadata)

pickle.dump([celltype_color_dict], open("colors.pickle", "wb"))

# %%
fig, ax = plt.subplots(1,1,figsize=(5,8))
for i, key in enumerate(list(celltype_color_dict.keys())):
    ax.scatter(0.001, len(celltype_color_dict) - i, c=celltype_color_dict[key], s=100)
    ax.text(0.002, len(celltype_color_dict) - i, key, 
            horizontalalignment='left',
            verticalalignment="center",
            fontdict={"size":16}
           )
    ax.set_xlim(0, 0.01)
    ax.axis("off")

# %%
ns.metadata["CellType"] = metadata.loc[ns.metadata.index, "Celltype"]
clusters = pd.read_csv("clusters.csv", index_col=[0])
ns.metadata['Cluster'] = clusters.loc[ns.metadata.index, "Cluster"]
ns.metadata["CellType_note"] = metadata.loc[ns.metadata.index, "Celltype_note"]

# %%
pickle.dump([ns], open("neuron_set.pickle", "wb"))

# %%
ns.features['projection_features'].normalize(log=True)
pickle.dump([ns.features['projection_features']], open("features_projection.pickle", "wb"))

# %%
ns.features['projection_features'].scaled_data

# %% [markdown]
# ## Feature 2: soma locations

# %%
pickle.dump([ns.features['soma_features']], open("features_soma.pickle", "wb"))

# %% [markdown]
# ## Feature 3: axon morphological features

# %%
# 1. Axon overall
df1 = pd.read_csv("../Data/swc/mapped/Data_for_analysis/features/axon.features", 
                          header=[0], index_col=[0], delimiter="\t").transpose()
df1.rename(columns={'Number of Bifurcatons':'Number of Bifurcations'}, inplace=True)

use_cols = ['Number of Stems', 
            'Overall Width', 'Overall Height', 'Overall Depth', 
            'Total Length', 
            'Max Euclidean Distance', 'Max Path Distance', 
            'Number of Bifurcations', 'Number of Branches', 'Number of Tips',
            'Max Branch Order','Average Contraction', 'Average Fragmentation',
            'Average Bifurcation Angle Local', 'Average Bifurcation Angle Remote', 
            'Hausdorff Dimension'
           ]
df1 = df1[use_cols]

feature_name = use_cols
new_feature_name = ['A_'+i.replace(' ', '_') for i in use_cols]
df1.rename(columns=dict(zip(feature_name, new_feature_name)), inplace=True)

# %%
# 2. Local axon
df2 = pd.read_csv("../Data/swc/mapped/Data_for_analysis/features/axon.features", 
                          header=[0], index_col=[0], delimiter="\t").transpose()
df2.rename(columns={'Number of Bifurcatons':'Number of Bifurcations'}, inplace=True)

use_cols = ['Number of Stems', 
            'Overall Width', 'Overall Height', 'Overall Depth', 
            'Total Length', 
            'Max Euclidean Distance', 'Max Path Distance', 
            'Number of Bifurcations', 'Number of Branches', 'Number of Tips',
            'Max Branch Order','Average Contraction', 'Average Fragmentation',
            'Average Bifurcation Angle Local', 'Average Bifurcation Angle Remote', 
            'Hausdorff Dimension'
           ]
df2 = df2[use_cols]

feature_name = use_cols
new_feature_name = ['AL_'+i.replace(' ', '_') for i in use_cols]
df2.rename(columns=dict(zip(feature_name, new_feature_name)), inplace=True)

# %%
df = pd.concat([df1, df2], axis=1)
lm_axon = nmt.features("L-measure of axon")
lm_axon.add_raw_data(df)

pickle.dump([lm_axon], open("features_lm_axon.pickle", "wb"))

# %% [markdown]
# ## Feature 4: dendrite morphological features

# %%
df = pd.read_csv("../Data/swc/mapped/Data_for_analysis/features/axon.features", 
                          header=[0], index_col=[0], delimiter="\t").transpose()
df.rename(columns={'Number of Bifurcatons':'Number of Bifurcations'}, inplace=True)

use_cols = ['Number of Stems', 
            'Overall Width', 'Overall Height', 'Overall Depth', 
            'Total Length', 
            'Max Euclidean Distance', 'Max Path Distance', 
            'Number of Bifurcations', 'Number of Branches', 'Number of Tips',
            'Max Branch Order','Average Contraction', 'Average Fragmentation',
            'Average Bifurcation Angle Local', 'Average Bifurcation Angle Remote', 
            'Hausdorff Dimension'
           ]
df = df[use_cols]

feature_name = use_cols
new_feature_name = ['D_'+i.replace(' ', '_') for i in use_cols]
df.rename(columns=dict(zip(feature_name, new_feature_name)), inplace=True)

lm_dendrite = nmt.features("L-measure of dendrite")
lm_dendrite.add_raw_data(df)

pickle.dump([lm_dendrite], open("features_lm_dendrite.pickle", "wb"))

# %%
print(np.log(10000), np.log(5000))
